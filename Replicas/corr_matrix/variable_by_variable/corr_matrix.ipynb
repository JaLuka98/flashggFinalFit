# %%
import uproot
import os
import glob
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib.colors import LinearSegmentedColormap
import mplhep as hep
import seaborn as sns
import ROOT
import pandas as pd
from scipy import stats
import numpy as np
from scipy.optimize import minimize, curve_fit
from scipy.stats import moment
import json
from itertools import combinations

# %%
# Importing translation dictionary
translationFilePath = "/work/niharrin/t35/CMSSW_14_1_0_pre4/src/flashggFinalFit/Replicas/corr_matrix/translation.json"
with open(translationFilePath) as translationFile:
    translation = json.load(translationFile)

# %%
def pois_untrimmed(toyDir_, poi_list_):
    pois = {}

    for current_poi in poi_list_:

        pois[current_poi] = []

    for i in range(len(glob.glob(os.path.join(toyDir_, "toy_*")))):

        if i%100==0:
            print(f"Processing fit_{i}")

        try:
            current_root_files = uproot.open(f"{toyDir_}/toy_{i}/higgsCombinefirstStep.MultiDimFit.mH125.38.root")
            # current_root_files = uproot.open(f"{toyDir_}/toy_{i}/higgsCombinefirstStep.MultiDimFit.mH125.root")
        except:
            print(f"Skipping fit_{i}: Required scan files not found")
            for current_poi in poi_list_:
                pois[current_poi].append(-999.0)
            continue

        for j, current_poi in enumerate(poi_list_):

            try: 
                current_tree = current_root_files["limit"]
            except:
                print(f"Skipping fit_{i}: Tree 'limit' not found in ROOT file")
                pois[current_poi].append(-999.0)
                continue

            current_limit_values = current_tree[current_poi].array()

            try:
                if current_limit_values[0]<-4:
                    print("Value out of boundary", current_limit_values[0], i)
            except:
                if j == 0:
                    print("Empty ROOT file for bootstrap: ", i)
                pois[current_poi].append(-999.0)
                continue

            pois[current_poi].append(float(current_limit_values[0]))
    return pois

# %%
def pois_trimmed(toyDir_, poi_list_, trimming_value_left_, trimming_value_right_):
    pois = {}

    for current_poi in poi_list_:

        pois[current_poi] = []

    for i in range(len(glob.glob(os.path.join(toyDir_, "toy_*")))):

        if i%100==0:
            print(f"Processing fit_{i}")

        try:
            current_root_files = uproot.open(f"{toyDir_}/toy_{i}/higgsCombinefirstStep.MultiDimFit.mH125.38.root")
            # current_root_files = uproot.open(f"{toyDir_}/toy_{i}/higgsCombinefirstStep.MultiDimFit.mH125.root")
        except:
            print(f"Skipping fit_{i}: Required scan files not found")
            for current_poi in poi_list_:
                pois[current_poi].append(-999.0)
            continue

        kill_event = False

        # First loop to check if there are outliers (outliers are events smaller than -4 and bigger than 4)
        for j, current_poi in enumerate(poi_list_):
            try: 
                current_tree = current_root_files["limit"]
            except:
                print(f"Skipping fit_{i}: Tree 'limit' not found in ROOT file")
                pois[current_poi].append(-999.0)
                continue

            current_limit_values = current_tree[current_poi].array()

            try:
                if (current_limit_values[0] > trimming_value_right_) or (current_limit_values[0] < trimming_value_left_):
                    kill_event = True 
                    break
            except:
                if j == 0:
                    print("Empty ROOT file for bootstrap: ", i)
                pois[current_poi].append(-999.0)
                continue

        if kill_event:
            print(f"Skipping fit_{i} with {current_limit_values[0]}: Outlier found")
            for current_poi in poi_list_:
                pois[current_poi].append(-999.0)
            continue

        for j, current_poi in enumerate(poi_list_):

            try: 
                current_tree = current_root_files["limit"]
            except:
                print(f"Skipping fit_{i}: Tree 'limit' not found in ROOT file")
                continue

            current_limit_values = current_tree[current_poi].array()

            try:
                if current_limit_values[0]<-4:
                    print("Value out of boundary", current_limit_values[0], i)
            except:
                if j == 0:
                    print("Empty ROOT file for bootstrap: ", i)
                continue

            pois[current_poi].append(float(current_limit_values[0]))
    return pois

# %%
def create_json_untrimmed(variable_, toyDir_, poi_list_, extra_name=""):
    # Loop through all fit directories (fit_0, fit_1, etc.)
    if not os.path.exists(f'pois_untrimmed_{variable_}{extra_name}.json'):
        pois = pois_untrimmed(toyDir_, poi_list_)
        # Save the POIs to a JSON file
        with open(f'pois_untrimmed_{variable_}{extra_name}.json', 'w') as f:
            json.dump(pois, f)
    else:
        # Load the POIs from the JSON file
        with open(f'pois_untrimmed_{variable_}{extra_name}.json', 'r') as f:
            pois = json.load(f)

    return pois

# %%
def gaus(x, amp, mu, sigma):
    return amp * np.exp(-(x - mu)**2 / (2 * sigma**2))

def create_json_trimmed(variable_, toyDir_, pois_untrimmed_, poi_list_, subfolder_, extra_name=""):

    # Now we have to fit a gaussian core to all the categories to get the values where we cut. z is the number of standard deviations we want to cut away
    trimming_value_left = 0
    trimming_value_right = 0
    largest_sigma = 0
    mu_to_largest_sigma = 0
    z = 4 # 4
    for i, current_poi in enumerate(poi_list_):
        r = np.array(pois_untrimmed_[current_poi])
        r = r[r > -998.0]
        mean = np.mean(r)
        s = np.std(r)
        # r = r[r < 5.0]
        
        bins = 100 # 30
        
        counts, bin_edges = np.histogram(r, bins=bins, density=False)
        bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

        popt, _ = curve_fit(gaus, bin_centers, counts, p0=[1, mean, s], maxfev=10000)
        amp_fit, mu_fit, sigma_fit = popt

        if i == 0:
            largest_sigma = sigma_fit
            mu_to_largest_sigma = mu_fit
        else:
            if (sigma_fit > largest_sigma):
                largest_sigma = sigma_fit
                mu_to_largest_sigma = mu_fit

        if (not os.path.exists(f"./Plots/{variable_}/{subfolder_}")) & (f"./Plots/{variable_}/{subfolder_}"!=""):
            os.makedirs(f"./Plots/{variable_}/{subfolder_}")
        

        plt.figure(figsize=(12, 8))
        plt.style.use(hep.style.CMS)
        hep.cms.label('Preliminary', data=False, lumi=9.5, com=13.6)
        plt.hist(r, bins=bins, density=False, alpha=0.6, label='S+B Toys') #30
        plt.plot(bin_centers, gaus(bin_centers, *popt), color='red', label='Fitted Gaussian')
        plt.axvline(mean, color='red', linestyle='--', label=f'Mean: {mean:.2f} ± {s:.2f}')
        plt.axvline(np.median(r), color='blue', linestyle='--', label=f'Median: {np.median(r):.2f}')
        plt.axvline(1.0, color='grey', linestyle='--', label=r'$\mu=1$')
        plt.legend()
        plt.xlabel(f"{translation[f'{current_poi}']}")
        plt.ylabel(r'$N$')
        plt.savefig(f"./Plots/{variable_}/{subfolder_}/gaussian_fit_{current_poi}.png")
        plt.close()

    trimming_value_left = mu_to_largest_sigma - z*largest_sigma
    trimming_value_right = mu_to_largest_sigma + z*largest_sigma

    print("Trimming values: ", trimming_value_left, trimming_value_right)

    if trimming_value_left > trimming_value_right:
        trimming_value_left, trimming_value_right = trimming_value_right, trimming_value_left

    if not os.path.exists(f'pois_trimmed_{variable_}{extra_name}.json'):
        pois = pois_trimmed(toyDir_, poi_list_, trimming_value_left, trimming_value_right)
        # Save the POIs to a JSON file
        with open(f'pois_trimmed_{variable_}{extra_name}.json', 'w') as f:
            json.dump(pois, f)
    else:
        # Load the POIs from the JSON file
        with open(f'pois_trimmed_{variable_}{extra_name}.json', 'r') as f:
            pois = json.load(f)
    
    return pois

# %%
def plot_all_individual_correlation(pois_, poi_list_, variable_):

    unique_pairings = list(combinations(poi_list_, 2))

    for current_tuple in unique_pairings:
        r_1, r_2 = current_tuple
        
        plot_individual_correlation([x for x in pois_[r_1] if x > -998.0], [x for x in pois_[r_2] if x > -998.0], r_1, r_2, np.corrcoef([x for x in pois_[r_1] if x > -998.0], [x for x in pois_[r_2] if x > -998.0])[0,1], folder=f"Plots/{variable_}")

def plot_individual_correlation(x_vals, y_vals, x_name, y_name, rho_, folder=""):
    # rho is here a number
    if (not os.path.exists(folder)) & (folder!=""):
        os.makedirs(folder)
    plt.style.use(hep.style.CMS)
    _, ax = plt.subplots(figsize=(12, 7))
    hep.cms.label('Preliminary', data=False, lumi=9.5, com=13.6)
    ax.scatter(x_vals, y_vals, color="black", marker="x", label="Manual Toys")
    ax.set_xlabel(translation[x_name])
    ax.set_ylabel(translation[y_name])
    bbox_props = dict(boxstyle="round", facecolor="white", alpha=0.9, edgecolor="black")
    ax.text(0.05, 0.175, f"$\\rho = {rho_:.3f}$", transform=ax.transAxes, bbox=bbox_props, fontsize=18)
    leg = ax.legend(fancybox=True, loc="lower right", frameon=True)
    leg.get_frame().set_alpha(0.9)  # Now this actually applies
    plt.savefig(os.path.join(folder, f"{x_name}_vs_{y_name}.pdf"), bbox_inches='tight')
    plt.savefig(os.path.join(folder, f"{x_name}_vs_{y_name}.png"), bbox_inches='tight')
    plt.close()

# %%
plot_dir = "Plots"
os.makedirs(plot_dir, exist_ok=True)

# %%
# Load PTH toys
variable = "PTH"
# sample_dir = '/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2025_06_12/intermediateRun3/finalfits'
sample_dir = '/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2025_09_06_powheg/finalfits'
main_dir = os.path.join(sample_dir, variable, "Combine", f"runFits_{variable}")
toyDir = os.path.join(main_dir, "toyFit")

poi_list = ["r_PTH_0p0_15p0", "r_PTH_15p0_30p0", "r_PTH_30p0_45p0", "r_PTH_45p0_80p0", "r_PTH_80p0_120p0", "r_PTH_120p0_200p0", "r_PTH_200p0_350p0", "r_PTH_350p0_10000p0"]

pois_untrimmed_PTH = create_json_untrimmed(variable, toyDir, poi_list)
pois_PTH = create_json_trimmed(variable, toyDir, pois_untrimmed_PTH, poi_list, subfolder_=f"SL_{variable}")

plot_all_individual_correlation(pois_PTH, poi_list, variable)
# Out:
# Trimming values:  -7.904995711526926 11.867931425809008

# %%
# df_PTH = pd.DataFrame(pois_untrimmed_PTH)
# print(df_PTH[(df_PTH['r_PTH_350p0_10000p0'] > -998.0) & (df_PTH['r_PTH_350p0_10000p0'] < -15.8)]['r_PTH_350p0_10000p0'].index.tolist())

# %%
# Load NJ toys
variable = "NJ"
# sample_dir = '/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2025_06_12/intermediateRun3/finalfits'
sample_dir = '/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2025_09_06_powheg/finalfits'
main_dir = os.path.join(sample_dir, variable, "Combine", f"runFits_{variable}")
toyDir = os.path.join(main_dir, "toyFit")

poi_list_NJ = ["r_NJ_0p0_1p0", "r_NJ_1p0_2p0", "r_NJ_2p0_3p0", "r_NJ_3p0_100p0"]

pois_untrimmed_NJ = create_json_untrimmed(variable, toyDir, poi_list_NJ)
pois_NJ = create_json_trimmed(variable, toyDir, pois_untrimmed_NJ, poi_list_NJ, subfolder_=f"SL_{variable}")

plot_all_individual_correlation(pois_untrimmed_NJ, poi_list_NJ, variable)
# Out:
# Trimming values:  -6.216481876670235 8.092867455798013

# %%
# Load PTJ0 toys
variable = "PTJ0"
# sample_dir = '/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2025_06_12/intermediateRun3/finalfits'
sample_dir = '/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2025_09_06_powheg/finalfits'
main_dir = os.path.join(sample_dir, variable, "Combine", f"runFits_{variable}")
toyDir = os.path.join(main_dir, "toyFit")

poi_list_PTJ0 = ["r_PTJ0_0p0_30p0", "r_PTJ0_30p0_75p0", "r_PTJ0_75p0_120p0", "r_PTJ0_120p0_200p0", "r_PTJ0_200p0_10000p0"]

pois_untrimmed_PTJ0 = create_json_untrimmed(variable, toyDir, poi_list_PTJ0)
pois_PTJ0 = create_json_trimmed(variable, toyDir, pois_untrimmed_PTJ0, poi_list_PTJ0, subfolder_=f"SL_{variable}")

plot_all_individual_correlation(pois_untrimmed_PTJ0, poi_list_PTJ0, variable)
# Out:
# Processing fit_0
# Empty ROOT file for bootstrap:  2
# Empty ROOT file for bootstrap:  14
# Value out of boundary -8.0 22
# Value out of boundary -4.199725 27
# Value out of boundary -4.0092134 30
# Value out of boundary -7.9999986 35
# Value out of boundary -7.999999 36
# Value out of boundary -7.5663433 51
# Value out of boundary -7.999999 66
# Value out of boundary -7.9999986 98
# Processing fit_100
# Value out of boundary -4.900538 110
# Value out of boundary -7.999999 158
# Empty ROOT file for bootstrap:  160
# Value out of boundary -8.0 161
# Value out of boundary -6.6480966 168
# Processing fit_200
# Value out of boundary -5.3540053 227
# Value out of boundary -6.92643 246
# Empty ROOT file for bootstrap:  293
# Processing fit_300
# Value out of boundary -7.3348856 306
# Empty ROOT file for bootstrap:  313
# Empty ROOT file for bootstrap:  332
# Empty ROOT file for bootstrap:  363
# Value out of boundary -8.0 380
# Empty ROOT file for bootstrap:  384
# Value out of boundary -7.999998 385
# Processing fit_400
# Empty ROOT file for bootstrap:  448
# Empty ROOT file for bootstrap:  456
# Value out of boundary -7.9999967 461
# Value out of boundary -4.647947 480
# Empty ROOT file for bootstrap:  488
# Value out of boundary -6.599804 495
# Processing fit_500
# Value out of boundary -8.0 508
# Value out of boundary -5.345126 510
# Value out of boundary -4.8365154 531
# Value out of boundary -7.999999 550
# Empty ROOT file for bootstrap:  552
# Empty ROOT file for bootstrap:  560
# Value out of boundary -4.077062 582
# Processing fit_600
# Value out of boundary -6.669978 626
# Empty ROOT file for bootstrap:  627
# Empty ROOT file for bootstrap:  628
# Value out of boundary -8.0 657
# Empty ROOT file for bootstrap:  676
# Value out of boundary -4.1581283 678
# Empty ROOT file for bootstrap:  681
# Empty ROOT file for bootstrap:  682
# Value out of boundary -8.0 692
# Processing fit_700
# Value out of boundary -6.3018513 771
# Value out of boundary -4.1855516 787
# Value out of boundary -4.166004 789
# Processing fit_800
# Value out of boundary -7.8499284 823
# Empty ROOT file for bootstrap:  863
# Value out of boundary -7.9999995 868
# Value out of boundary -5.598666 869
# Value out of boundary -6.4316716 875
# Value out of boundary -5.1779385 891
# Empty ROOT file for bootstrap:  896
# Processing fit_900
# Value out of boundary -5.233816 927
# Empty ROOT file for bootstrap:  942
# Value out of boundary -5.61833 986
# Value out of boundary -8.0 989
# Empty ROOT file for bootstrap:  997
# Processing fit_1000
# Value out of boundary -4.052951 1004
# Value out of boundary -5.235387 1008
# Empty ROOT file for bootstrap:  1025
# Empty ROOT file for bootstrap:  1042
# Value out of boundary -8.0 1043
# Value out of boundary -7.9999986 1060
# Empty ROOT file for bootstrap:  1071
# Value out of boundary -5.1643763 1084
# Empty ROOT file for bootstrap:  1091
# Processing fit_1100
# Empty ROOT file for bootstrap:  1103
# Value out of boundary -4.9692235 1107
# Value out of boundary -5.4696965 1108
# Value out of boundary -4.537449 1133
# Value out of boundary -4.2403193 1153
# Value out of boundary -6.6016016 1184
# Processing fit_1200
# Value out of boundary -8.0 1200
# Value out of boundary -8.0 1209
# Value out of boundary -7.9999986 1214
# Value out of boundary -6.3523583 1234
# Empty ROOT file for bootstrap:  1255
# Value out of boundary -7.2560797 1260
# Value out of boundary -7.0033727 1268
# Value out of boundary -4.169419 1288
# Empty ROOT file for bootstrap:  1295
# Processing fit_1300
# Empty ROOT file for bootstrap:  1301
# Value out of boundary -5.744191 1303
# Empty ROOT file for bootstrap:  1305
# Value out of boundary -5.2325363 1318
# Value out of boundary -4.20891 1329
# Value out of boundary -8.0 1347
# Value out of boundary -4.1150074 1361
# Value out of boundary -7.33575 1362
# Value out of boundary -7.8949637 1391
# Processing fit_1400
# Empty ROOT file for bootstrap:  1419
# Empty ROOT file for bootstrap:  1424
# Value out of boundary -7.9999986 1434
# Value out of boundary -7.9999995 1439
# Value out of boundary -4.47648 1459
# Value out of boundary -8.0 1473
# Processing fit_1500
# Value out of boundary -8.0 1507
# Empty ROOT file for bootstrap:  1508
# Value out of boundary -7.9999294 1545
# Empty ROOT file for bootstrap:  1566
# Value out of boundary -7.999999 1571
# Empty ROOT file for bootstrap:  1573
# Empty ROOT file for bootstrap:  1580
# Value out of boundary -8.0 1598
# Processing fit_1600
# Value out of boundary -7.999997 1601
# Value out of boundary -7.9999933 1608
# Empty ROOT file for bootstrap:  1614
# Empty ROOT file for bootstrap:  1628
# Empty ROOT file for bootstrap:  1629
# Value out of boundary -6.1277328 1652
# Value out of boundary -6.779855 1659
# Value out of boundary -8.0 1665
# Empty ROOT file for bootstrap:  1691
# Value out of boundary -7.9999986 1695
# Processing fit_1700
# Empty ROOT file for bootstrap:  1773
# Empty ROOT file for bootstrap:  1787
# Processing fit_1800
# Value out of boundary -7.999999 1801
# Empty ROOT file for bootstrap:  1802
# Empty ROOT file for bootstrap:  1818
# Empty ROOT file for bootstrap:  1861
# Value out of boundary -4.206762 1891
# Processing fit_1900
# Value out of boundary -4.9946947 1919
# Value out of boundary -4.807727 1938
# Value out of boundary -5.2270365 1948
# Empty ROOT file for bootstrap:  1971
# Processing fit_2000
# Empty ROOT file for bootstrap:  2003
# Empty ROOT file for bootstrap:  2007
# Value out of boundary -7.999998 2017
# Empty ROOT file for bootstrap:  2018
# Value out of boundary -4.4340925 2029
# Value out of boundary -4.2822156 2035
# Empty ROOT file for bootstrap:  2038
# Empty ROOT file for bootstrap:  2048
# Value out of boundary -4.3338666 2059
# Value out of boundary -5.0034704 2089
# Processing fit_2100
# Value out of boundary -6.354487 2109
# Value out of boundary -6.191615 2126
# Value out of boundary -7.9999995 2129
# Value out of boundary -4.2543373 2134
# Value out of boundary -7.6650248 2138
# Value out of boundary -4.01663 2145
# Value out of boundary -5.098856 2166
# Empty ROOT file for bootstrap:  2174
# Empty ROOT file for bootstrap:  2183
# Processing fit_2200
# Value out of boundary -4.2828493 2204
# Value out of boundary -5.5237556 2210
# Value out of boundary -4.109665 2232
# Value out of boundary -8.0 2261
# Empty ROOT file for bootstrap:  2272
# Value out of boundary -5.597021 2296
# Processing fit_2300
# Empty ROOT file for bootstrap:  2327
# Value out of boundary -5.170749 2365
# Value out of boundary -7.619378 2379
# Value out of boundary -6.8991385 2385
# Processing fit_2400
# Empty ROOT file for bootstrap:  2416
# Value out of boundary -8.0 2428
# Empty ROOT file for bootstrap:  2434
# Value out of boundary -4.691903 2438
# Value out of boundary -4.4678802 2441
# Value out of boundary -7.312611 2479
# Value out of boundary -4.4683905 2486
# Value out of boundary -7.0773077 2486
# Value out of boundary -4.1486974 2493
# Processing fit_2500
# Value out of boundary -4.89534 2542
# Value out of boundary -8.0 2566
# Empty ROOT file for bootstrap:  2574
# Value out of boundary -8.0 2594
# Processing fit_2600
# Value out of boundary -6.002458 2603
# Value out of boundary -7.9999995 2607
# Empty ROOT file for bootstrap:  2612
# Value out of boundary -4.4323435 2617
# Value out of boundary -8.0 2651
# Value out of boundary -5.056713 2678
# Value out of boundary -8.0 2684
# Empty ROOT file for bootstrap:  2686
# Processing fit_2700
# Value out of boundary -4.4902606 2701
# Empty ROOT file for bootstrap:  2722
# Value out of boundary -5.6612177 2723
# Value out of boundary -8.0 2725
# Value out of boundary -6.1412354 2743
# Value out of boundary -8.0 2765
# Empty ROOT file for bootstrap:  2779
# Value out of boundary -6.8994603 2783
# Value out of boundary -4.3575892 2792
# Empty ROOT file for bootstrap:  2799
# Processing fit_2800
# Value out of boundary -7.4550514 2817
# Value out of boundary -4.5038466 2830
# Empty ROOT file for bootstrap:  2867
# Value out of boundary -5.113085 2882
# Value out of boundary -8.0 2889
# Processing fit_2900
# Value out of boundary -6.5424304 2917
# Value out of boundary -6.3694053 2951
# Empty ROOT file for bootstrap:  2956
# Value out of boundary -5.191703 2959
# Value out of boundary -5.6979537 2960
# Value out of boundary -4.6154823 2966
# Value out of boundary -4.555879 2985
# Empty ROOT file for bootstrap:  2995
# Processing fit_3000
# Value out of boundary -6.080353 3001
# Value out of boundary -8.0 3008
# Empty ROOT file for bootstrap:  3014
# Value out of boundary -4.2270403 3031
# Empty ROOT file for bootstrap:  3052
# Value out of boundary -6.6298633 3082
# Empty ROOT file for bootstrap:  3090
# Processing fit_3100
# Empty ROOT file for bootstrap:  3149
# Value out of boundary -8.0 3155
# Empty ROOT file for bootstrap:  3163
# Value out of boundary -8.0 3187
# Value out of boundary -7.9999995 3190
# Processing fit_3200
# Value out of boundary -8.0 3200
# Empty ROOT file for bootstrap:  3216
# Empty ROOT file for bootstrap:  3218
# Value out of boundary -8.0 3221
# Value out of boundary -4.555509 3235
# Value out of boundary -6.4935265 3272
# Processing fit_3300
# Value out of boundary -5.8440866 3307
# Value out of boundary -7.999995 3328
# Value out of boundary -4.5794387 3340
# Value out of boundary -6.179387 3372
# Empty ROOT file for bootstrap:  3397
# Processing fit_3400
# Empty ROOT file for bootstrap:  3436
# Value out of boundary -7.9999995 3458
# Value out of boundary -4.4692698 3468
# Value out of boundary -6.4335318 3472
# Empty ROOT file for bootstrap:  3480
# Value out of boundary -7.8996677 3491
# Value out of boundary -5.4104404 3499
# Processing fit_3500
# Value out of boundary -7.736898 3509
# Value out of boundary -4.480283 3524
# Value out of boundary -4.147224 3536
# Value out of boundary -5.5813437 3550
# Value out of boundary -8.0 3573
# Value out of boundary -6.070352 3579
# Value out of boundary -4.1951323 3593
# Processing fit_3600
# Value out of boundary -8.0 3600
# Value out of boundary -7.999998 3606
# Empty ROOT file for bootstrap:  3609
# Value out of boundary -4.756409 3616
# Value out of boundary -6.1838217 3624
# Value out of boundary -6.03025 3630
# Value out of boundary -7.9999995 3643
# Value out of boundary -6.783864 3648
# Value out of boundary -4.1210556 3654
# Value out of boundary -8.0 3655
# Value out of boundary -6.5978136 3657
# Value out of boundary -7.9999995 3666
# Value out of boundary -4.9433966 3679
# Processing fit_3700
# Value out of boundary -6.072416 3717
# Empty ROOT file for bootstrap:  3719
# Empty ROOT file for bootstrap:  3733
# Value out of boundary -4.9958816 3750
# Value out of boundary -5.6702332 3753
# Empty ROOT file for bootstrap:  3758
# Value out of boundary -5.6893125 3762
# Value out of boundary -8.0 3780
# Processing fit_3800
# Empty ROOT file for bootstrap:  3822
# Value out of boundary -8.0 3875
# Value out of boundary -5.8361726 3890
# Processing fit_3900
# Value out of boundary -8.0 3902
# Empty ROOT file for bootstrap:  3906
# Empty ROOT file for bootstrap:  3909
# Value out of boundary -5.7368016 3916
# Value out of boundary -6.355191 3923
# Value out of boundary -8.0 3927
# Value out of boundary -5.7399282 3929
# Empty ROOT file for bootstrap:  3946
# Value out of boundary -5.593104 3947
# Value out of boundary -8.0 3968
# Empty ROOT file for bootstrap:  3980
# Processing fit_4000
# Empty ROOT file for bootstrap:  4008
# Value out of boundary -5.578783 4011
# Value out of boundary -5.238144 4016
# Value out of boundary -5.4126143 4029
# Value out of boundary -5.659486 4042
# Empty ROOT file for bootstrap:  4056
# Value out of boundary -8.0 4057
# Empty ROOT file for bootstrap:  4061
# Empty ROOT file for bootstrap:  4089
# Value out of boundary -6.201548 4099
# Processing fit_4100
# Empty ROOT file for bootstrap:  4119
# Value out of boundary -7.9999986 4126
# Processing fit_4200
# Value out of boundary -8.0 4207
# Value out of boundary -7.887657 4213
# Empty ROOT file for bootstrap:  4233
# Value out of boundary -4.51623 4259
# Empty ROOT file for bootstrap:  4261
# Value out of boundary -6.1203227 4263
# Value out of boundary -7.9999995 4272
# Value out of boundary -7.999998 4279
# Value out of boundary -4.43354 4297
# Processing fit_4300
# Empty ROOT file for bootstrap:  4314
# Empty ROOT file for bootstrap:  4325
# Value out of boundary -5.5726957 4326
# Empty ROOT file for bootstrap:  4349
# Value out of boundary -7.1834526 4366
# Value out of boundary -7.25924 4383
# Value out of boundary -5.210409 4398
# Processing fit_4400
# Value out of boundary -7.2238574 4400
# Empty ROOT file for bootstrap:  4409
# Value out of boundary -4.0354786 4412
# Empty ROOT file for bootstrap:  4422
# Value out of boundary -6.506564 4428
# Empty ROOT file for bootstrap:  4430
# Empty ROOT file for bootstrap:  4444
# Value out of boundary -6.7300773 4454
# Skipping fit_4462: Required scan files not found
# Empty ROOT file for bootstrap:  4475
# Processing fit_4500
# Empty ROOT file for bootstrap:  4501
# Value out of boundary -5.208575 4507
# Empty ROOT file for bootstrap:  4520
# Empty ROOT file for bootstrap:  4542
# Value out of boundary -8.0 4562
# Value out of boundary -8.0 4568
# Value out of boundary -4.3111787 4572
# Empty ROOT file for bootstrap:  4576
# Processing fit_4600
# Empty ROOT file for bootstrap:  4616
# Value out of boundary -7.079816 4654
# Value out of boundary -4.4315524 4667
# Empty ROOT file for bootstrap:  4679
# Value out of boundary -4.1832223 4682
# Value out of boundary -7.417173 4690
# Value out of boundary -7.3025103 4695
# Processing fit_4700
# Value out of boundary -4.9349627 4730
# Value out of boundary -7.5631633 4735
# Value out of boundary -7.9999995 4744
# Value out of boundary -5.0986514 4746
# Value out of boundary -8.0 4776
# Value out of boundary -4.0677733 4786
# Empty ROOT file for bootstrap:  4795
# Empty ROOT file for bootstrap:  4799
# Processing fit_4800
# Empty ROOT file for bootstrap:  4814
# Value out of boundary -6.2676373 4815
# Value out of boundary -6.0681868 4825
# Empty ROOT file for bootstrap:  4831
# Empty ROOT file for bootstrap:  4833
# Empty ROOT file for bootstrap:  4843
# Value out of boundary -8.0 4857
# Value out of boundary -5.5390177 4860
# Value out of boundary -4.039967 4884
# Empty ROOT file for bootstrap:  4888
# Processing fit_4900
# Value out of boundary -6.5714536 4909
# Value out of boundary -7.745668 4918
# Empty ROOT file for bootstrap:  4969
# Empty ROOT file for bootstrap:  4982
# Processing fit_5000
# Empty ROOT file for bootstrap:  5011
# Value out of boundary -8.0 5013
# Value out of boundary -7.4634557 5023
# Empty ROOT file for bootstrap:  5060
# Empty ROOT file for bootstrap:  5066
# Value out of boundary -4.2041435 5085
# Value out of boundary -4.2371526 5090
# Processing fit_5100
# Empty ROOT file for bootstrap:  5140
# Empty ROOT file for bootstrap:  5141
# Empty ROOT file for bootstrap:  5144
# Value out of boundary -7.1076 5158
# Empty ROOT file for bootstrap:  5179
# Value out of boundary -5.27816 5181
# Value out of boundary -5.5303755 5184
# Processing fit_5200
# Value out of boundary -4.9732943 5235
# Empty ROOT file for bootstrap:  5244
# Value out of boundary -7.9999976 5254
# Value out of boundary -7.9999995 5262
# Value out of boundary -5.526485 5285
# Value out of boundary -7.9999995 5287
# Processing fit_5300
# Empty ROOT file for bootstrap:  5305
# Empty ROOT file for bootstrap:  5315
# Empty ROOT file for bootstrap:  5320
# Value out of boundary -7.9999995 5328
# Empty ROOT file for bootstrap:  5332
# Value out of boundary -4.2845945 5346
# Empty ROOT file for bootstrap:  5357
# Value out of boundary -7.5063944 5368
# Value out of boundary -6.228662 5372
# Value out of boundary -5.1987753 5376
# Value out of boundary -5.2618904 5395
# Processing fit_5400
# Empty ROOT file for bootstrap:  5410
# Value out of boundary -5.8632083 5431
# Empty ROOT file for bootstrap:  5432
# Value out of boundary -8.0 5433
# Value out of boundary -7.7241464 5439
# Value out of boundary -6.0281744 5462
# Empty ROOT file for bootstrap:  5488
# Value out of boundary -5.0052123 5497
# Processing fit_5500
# Empty ROOT file for bootstrap:  5506
# Value out of boundary -5.627724 5516
# Value out of boundary -5.182627 5524
# Value out of boundary -5.067967 5526
# Empty ROOT file for bootstrap:  5539
# Value out of boundary -4.6397223 5597
# Processing fit_5600
# Value out of boundary -7.669672 5651
# Empty ROOT file for bootstrap:  5662
# Value out of boundary -4.8593187 5664
# Value out of boundary -4.9192395 5680
# Value out of boundary -6.909694 5683
# Value out of boundary -7.999999 5699
# Processing fit_5700
# Value out of boundary -6.6464005 5710
# Empty ROOT file for bootstrap:  5713
# Value out of boundary -5.1864376 5737
# Value out of boundary -7.821963 5744
# Empty ROOT file for bootstrap:  5763
# Value out of boundary -6.475207 5766
# Value out of boundary -5.5555325 5770
# Value out of boundary -6.0329714 5774
# Value out of boundary -4.7829432 5776
# Value out of boundary -4.3366923 5784
# Value out of boundary -5.4973845 5794
# Value out of boundary -5.778543 5796
# Processing fit_5800
# Empty ROOT file for bootstrap:  5827
# Empty ROOT file for bootstrap:  5855
# Empty ROOT file for bootstrap:  5861
# Value out of boundary -6.299539 5863
# Value out of boundary -8.0 5888
# Value out of boundary -8.0 5889
# Empty ROOT file for bootstrap:  5891
# Processing fit_5900
# Value out of boundary -4.2699127 5904
# Value out of boundary -8.0 5905
# Value out of boundary -6.887838 5921
# Value out of boundary -5.9182625 5934
# Value out of boundary -7.9999995 5942
# Value out of boundary -4.1008883 5961
# Value out of boundary -7.34623 5970
# Value out of boundary -5.9616437 5987
# Value out of boundary -6.347557 5996
# Processing fit_6000
# Value out of boundary -5.3382587 6006
# Empty ROOT file for bootstrap:  6018
# Empty ROOT file for bootstrap:  6053
# Value out of boundary -4.147882 6064
# Empty ROOT file for bootstrap:  6070
# Processing fit_6100
# Value out of boundary -5.2293367 6104
# Value out of boundary -7.999996 6171
# Value out of boundary -8.0 6181
# Value out of boundary -4.4944077 6183
# Processing fit_6200
# Value out of boundary -4.2026315 6207
# Value out of boundary -8.0 6225
# Value out of boundary -6.7071843 6231
# Value out of boundary -8.0 6254
# Value out of boundary -7.9999995 6264
# Value out of boundary -7.4979577 6272
# Value out of boundary -5.663031 6284
# Value out of boundary -5.304467 6299
# Processing fit_6300
# Value out of boundary -4.6848536 6311
# Value out of boundary -8.0 6323
# Value out of boundary -7.1353145 6340
# Empty ROOT file for bootstrap:  6346
# Value out of boundary -4.286875 6367
# Value out of boundary -5.9250336 6390
# Processing fit_6400
# Empty ROOT file for bootstrap:  6403
# Empty ROOT file for bootstrap:  6424
# Value out of boundary -7.360453 6431
# Value out of boundary -7.999999 6435
# Empty ROOT file for bootstrap:  6486
# Processing fit_6500
# Value out of boundary -4.8681846 6527
# Value out of boundary -4.482351 6549
# Value out of boundary -5.724032 6551
# Value out of boundary -7.9999995 6568
# Processing fit_6600
# Empty ROOT file for bootstrap:  6603
# Value out of boundary -7.9999614 6607
# Value out of boundary -8.0 6612
# Value out of boundary -7.999998 6624
# Empty ROOT file for bootstrap:  6626
# Value out of boundary -6.282665 6644
# Value out of boundary -8.0 6653
# Processing fit_6700
# Empty ROOT file for bootstrap:  6715
# Value out of boundary -5.6818485 6745
# Empty ROOT file for bootstrap:  6749
# Empty ROOT file for bootstrap:  6780
# Processing fit_6800
# Empty ROOT file for bootstrap:  6809
# Empty ROOT file for bootstrap:  6814
# Value out of boundary -4.911727 6823
# Value out of boundary -4.737011 6826
# Value out of boundary -5.6870704 6863
# Empty ROOT file for bootstrap:  6895
# Processing fit_6900
# Empty ROOT file for bootstrap:  6947
# Processing fit_7000
# Empty ROOT file for bootstrap:  7022
# Value out of boundary -7.2652993 7041
# Value out of boundary -4.563704 7053
# Value out of boundary -5.973872 7060
# Empty ROOT file for bootstrap:  7079
# Value out of boundary -5.4748306 7097
# Processing fit_7100
# Empty ROOT file for bootstrap:  7113
# Value out of boundary -7.9999995 7129
# Value out of boundary -6.7281456 7151
# Value out of boundary -8.0 7163
# Value out of boundary -8.0 7175
# Processing fit_7200
# Value out of boundary -6.316121 7220
# Value out of boundary -4.395723 7222
# Value out of boundary -7.999999 7229
# Empty ROOT file for bootstrap:  7266
# Value out of boundary -7.9243345 7284
# Empty ROOT file for bootstrap:  7290
# Empty ROOT file for bootstrap:  7298
# Empty ROOT file for bootstrap:  7299
# Processing fit_7300
# Value out of boundary -4.4621553 7309
# Empty ROOT file for bootstrap:  7322
# Empty ROOT file for bootstrap:  7323
# Value out of boundary -5.9079947 7329
# Value out of boundary -8.0 7329
# Value out of boundary -7.999999 7372
# Empty ROOT file for bootstrap:  7377
# Empty ROOT file for bootstrap:  7391
# Processing fit_7400
# Value out of boundary -7.9999995 7412
# Value out of boundary -7.999998 7429
# Empty ROOT file for bootstrap:  7447
# Value out of boundary -5.7291064 7451
# Value out of boundary -5.969459 7478
# Empty ROOT file for bootstrap:  7492
# Value out of boundary -8.0 7494
# Processing fit_7500
# Value out of boundary -7.9999995 7504
# Value out of boundary -6.4277334 7547
# Value out of boundary -7.8532443 7551
# Empty ROOT file for bootstrap:  7556
# Value out of boundary -8.0 7564
# Value out of boundary -7.999997 7577
# Processing fit_7600
# Value out of boundary -6.8101416 7603
# Value out of boundary -7.084191 7606
# Value out of boundary -6.2604227 7608
# Value out of boundary -5.974316 7616
# Empty ROOT file for bootstrap:  7629
# Empty ROOT file for bootstrap:  7630
# Empty ROOT file for bootstrap:  7637
# Value out of boundary -8.0 7646
# Value out of boundary -4.8696375 7668
# Value out of boundary -4.0402007 7670
# Empty ROOT file for bootstrap:  7683
# Processing fit_7700
# Empty ROOT file for bootstrap:  7723
# Value out of boundary -4.469627 7796
# Value out of boundary -5.9043803 7799
# Processing fit_7800
# Empty ROOT file for bootstrap:  7814
# Value out of boundary -7.720605 7822
# Value out of boundary -5.6229625 7827
# Value out of boundary -7.999999 7840
# Value out of boundary -8.0 7847
# Value out of boundary -4.917526 7868
# Value out of boundary -5.9441495 7878
# Empty ROOT file for bootstrap:  7881
# Empty ROOT file for bootstrap:  7889
# Value out of boundary -6.4830236 7894
# Processing fit_7900
# Value out of boundary -7.9999995 7900
# Value out of boundary -5.2838 7903
# Value out of boundary -8.0 7906
# Value out of boundary -6.1148806 7912
# Empty ROOT file for bootstrap:  7917
# Value out of boundary -7.9999986 7922
# Value out of boundary -7.999999 7929
# Value out of boundary -6.1157384 7932
# Value out of boundary -7.5776463 7957
# Empty ROOT file for bootstrap:  7958
# Value out of boundary -8.0 7959
# Empty ROOT file for bootstrap:  7976
# Value out of boundary -5.015525 7980
# Processing fit_8000
# Value out of boundary -4.2707615 8006
# Value out of boundary -8.0 8010
# Value out of boundary -4.0226955 8022
# Value out of boundary -8.0 8094
# Empty ROOT file for bootstrap:  8095
# Processing fit_8100
# Value out of boundary -8.0 8118
# Value out of boundary -7.999998 8132
# Empty ROOT file for bootstrap:  8142
# Empty ROOT file for bootstrap:  8151
# Empty ROOT file for bootstrap:  8155
# Value out of boundary -4.008511 8160
# Value out of boundary -6.114378 8168
# Value out of boundary -4.13835 8169
# Value out of boundary -5.161509 8173
# Value out of boundary -5.7720547 8181
# Value out of boundary -6.633834 8199
# Processing fit_8200
# Value out of boundary -5.051474 8204
# Value out of boundary -7.9999948 8238
# Value out of boundary -4.0859265 8266
# Processing fit_8300
# Value out of boundary -5.900545 8311
# Value out of boundary -7.9999995 8313
# Empty ROOT file for bootstrap:  8318
# Value out of boundary -4.024252 8328
# Value out of boundary -4.1825624 8349
# Value out of boundary -7.999997 8379
# Processing fit_8400
# Value out of boundary -4.1658144 8411
# Value out of boundary -7.3377233 8424
# Value out of boundary -6.8584547 8452
# Value out of boundary -7.0561934 8459
# Empty ROOT file for bootstrap:  8464
# Empty ROOT file for bootstrap:  8470
# Empty ROOT file for bootstrap:  8490
# Processing fit_8500
# Value out of boundary -7.999999 8530
# Value out of boundary -7.9999995 8535
# Value out of boundary -5.755157 8563
# Empty ROOT file for bootstrap:  8565
# Value out of boundary -4.0591526 8574
# Value out of boundary -8.0 8574
# Processing fit_8600
# Value out of boundary -6.4691014 8604
# Value out of boundary -7.999999 8635
# Value out of boundary -4.5471044 8636
# Value out of boundary -5.9201374 8657
# Empty ROOT file for bootstrap:  8670
# Value out of boundary -5.19331 8671
# Value out of boundary -8.0 8697
# Empty ROOT file for bootstrap:  8699
# Processing fit_8700
# Value out of boundary -4.774565 8700
# Value out of boundary -4.026932 8725
# Value out of boundary -8.0 8741
# Value out of boundary -8.0 8762
# Value out of boundary -5.866903 8772
# Empty ROOT file for bootstrap:  8781
# Processing fit_8800
# Value out of boundary -8.0 8810
# Empty ROOT file for bootstrap:  8818
# Value out of boundary -6.122767 8838
# Empty ROOT file for bootstrap:  8845
# Value out of boundary -4.21165 8865
# Value out of boundary -8.0 8869
# Value out of boundary -7.9999995 8898
# Processing fit_8900
# Value out of boundary -4.666137 8900
# Value out of boundary -4.9716964 8922
# Empty ROOT file for bootstrap:  8953
# Value out of boundary -6.639044 8958
# Value out of boundary -7.9999995 8969
# Processing fit_9000
# Empty ROOT file for bootstrap:  9002
# Value out of boundary -7.9999976 9012
# Value out of boundary -7.9999986 9016
# Value out of boundary -7.70138 9032
# Value out of boundary -8.0 9038
# Empty ROOT file for bootstrap:  9041
# Value out of boundary -4.0779305 9044
# Value out of boundary -5.2906523 9084
# Processing fit_9100
# Value out of boundary -7.9999995 9100
# Value out of boundary -8.0 9127
# Value out of boundary -4.893071 9141
# Value out of boundary -4.5275083 9148
# Empty ROOT file for bootstrap:  9179
# Processing fit_9200
# Empty ROOT file for bootstrap:  9211
# Value out of boundary -4.3766184 9220
# Value out of boundary -8.0 9239
# Empty ROOT file for bootstrap:  9252
# Empty ROOT file for bootstrap:  9275
# Value out of boundary -6.282653 9278
# Value out of boundary -7.999997 9286
# Value out of boundary -7.999998 9298
# Processing fit_9300
# Empty ROOT file for bootstrap:  9332
# Value out of boundary -7.880607 9385
# Processing fit_9400
# Empty ROOT file for bootstrap:  9437
# Value out of boundary -7.999998 9441
# Value out of boundary -4.566236 9474
# Value out of boundary -4.4740534 9488
# Value out of boundary -6.649547 9491
# Processing fit_9500
# Value out of boundary -4.784971 9501
# Empty ROOT file for bootstrap:  9509
# Value out of boundary -7.9999986 9518
# Value out of boundary -5.990817 9520
# Value out of boundary -6.7462068 9534
# Value out of boundary -4.6417136 9535
# Empty ROOT file for bootstrap:  9585
# Processing fit_9600
# Value out of boundary -7.903652 9601
# Value out of boundary -4.3448105 9642
# Empty ROOT file for bootstrap:  9645
# Value out of boundary -5.611555 9668
# Value out of boundary -7.9999995 9678
# Value out of boundary -6.660565 9690
# Empty ROOT file for bootstrap:  9698
# Processing fit_9700
# Value out of boundary -5.6125603 9745
# Value out of boundary -7.999998 9748
# Empty ROOT file for bootstrap:  9785
# Value out of boundary -7.999998 9791
# Empty ROOT file for bootstrap:  9792
# Value out of boundary -7.426946 9794
# Processing fit_9800
# Value out of boundary -6.0032606 9803
# Value out of boundary -8.0 9804
# Value out of boundary -4.6382318 9835
# Value out of boundary -5.2974153 9848
# Value out of boundary -7.9999957 9862
# Empty ROOT file for bootstrap:  9868
# Processing fit_9900
# Value out of boundary -5.9991465 9906
# Value out of boundary -8.0 9912
# Value out of boundary -4.6185837 9920
# Value out of boundary -5.3755546 9932
# Empty ROOT file for bootstrap:  9935
# Empty ROOT file for bootstrap:  9941
# Value out of boundary -8.0 9942
# Empty ROOT file for bootstrap:  9953
# Empty ROOT file for bootstrap:  9956
# Value out of boundary -4.7609096 9968
# Value out of boundary -4.5461745 9987
# Value out of boundary -5.2255764 9993
# Processing fit_10000
# Value out of boundary -7.4118576 10002
# Value out of boundary -5.751295 10008
# Empty ROOT file for bootstrap:  10024
# Value out of boundary -7.9999995 10044
# Processing fit_10100
# Value out of boundary -5.922517 10114
# Empty ROOT file for bootstrap:  10121
# Value out of boundary -4.083883 10123
# Empty ROOT file for bootstrap:  10129
# Value out of boundary -7.9999995 10133
# Empty ROOT file for bootstrap:  10143
# Value out of boundary -7.9999995 10149
# Empty ROOT file for bootstrap:  10150
# Value out of boundary -7.9999995 10178
# Value out of boundary -8.0 10184
# Value out of boundary -7.999999 10197
# Processing fit_10200
# Value out of boundary -7.9999995 10203
# Value out of boundary -7.771951 10221
# Value out of boundary -4.7719946 10234
# Empty ROOT file for bootstrap:  10270
# Value out of boundary -4.651849 10271
# Value out of boundary -8.0 10299
# Processing fit_10300
# Value out of boundary -4.608827 10344
# Value out of boundary -7.999986 10354
# Value out of boundary -7.999997 10372
# Processing fit_10400
# Value out of boundary -7.9999986 10407
# Value out of boundary -8.0 10440
# Empty ROOT file for bootstrap:  10441
# Value out of boundary -6.614758 10454
# Value out of boundary -7.05807 10466
# Empty ROOT file for bootstrap:  10470
# Value out of boundary -4.8744226 10477
# Value out of boundary -5.2520423 10488
# Value out of boundary -4.5312033 10489
# Processing fit_10500
# Value out of boundary -7.999999 10506
# Value out of boundary -8.0 10509
# Empty ROOT file for bootstrap:  10510
# Value out of boundary -7.4607487 10543
# Value out of boundary -6.691227 10563
# Value out of boundary -7.048986 10576
# Value out of boundary -5.741062 10591
# Processing fit_10600
# Empty ROOT file for bootstrap:  10626
# Empty ROOT file for bootstrap:  10668
# Value out of boundary -5.768106 10676
# Value out of boundary -4.452433 10689
# Processing fit_10700
# Value out of boundary -4.1371913 10706
# Empty ROOT file for bootstrap:  10710
# Empty ROOT file for bootstrap:  10743
# Value out of boundary -7.9999995 10771
# Value out of boundary -5.3624506 10775
# Value out of boundary -4.319436 10793
# Empty ROOT file for bootstrap:  10795
# Value out of boundary -4.731719 10799
# Processing fit_10800
# Empty ROOT file for bootstrap:  10813
# Value out of boundary -7.999999 10830
# Empty ROOT file for bootstrap:  10869
# Value out of boundary -4.2134876 10882
# Processing fit_10900
# Value out of boundary -5.43436 10902
# Empty ROOT file for bootstrap:  10914
# Empty ROOT file for bootstrap:  10931
# Value out of boundary -4.18395 10941
# Empty ROOT file for bootstrap:  10958
# Value out of boundary -7.6210938 10970
# Value out of boundary -7.096032 10974
# Value out of boundary -4.3222575 10990
# Value out of boundary -7.463227 10999
# Processing fit_11000
# Empty ROOT file for bootstrap:  11045
# Value out of boundary -6.0974855 11085
# Processing fit_11100
# Value out of boundary -5.1257796 11112
# Value out of boundary -7.51863 11114
# Value out of boundary -8.0 11116
# Empty ROOT file for bootstrap:  11128
# Value out of boundary -8.0 11137
# Value out of boundary -4.020083 11149
# Value out of boundary -5.789607 11167
# Processing fit_11200
# Value out of boundary -4.4647694 11245
# Empty ROOT file for bootstrap:  11256
# Value out of boundary -5.6668754 11268
# Value out of boundary -7.9999976 11282
# Empty ROOT file for bootstrap:  11298
# Processing fit_11300
# Empty ROOT file for bootstrap:  11302
# Empty ROOT file for bootstrap:  11305
# Empty ROOT file for bootstrap:  11306
# Empty ROOT file for bootstrap:  11316
# Empty ROOT file for bootstrap:  11340
# Value out of boundary -4.879845 11341
# Value out of boundary -6.4427295 11355
# Empty ROOT file for bootstrap:  11367
# Empty ROOT file for bootstrap:  11378
# Processing fit_11400
# Value out of boundary -5.3888173 11400
# Empty ROOT file for bootstrap:  11429
# Value out of boundary -8.0 11431
# Value out of boundary -6.9264374 11433
# Empty ROOT file for bootstrap:  11460
# Empty ROOT file for bootstrap:  11464
# Processing fit_11500
# Value out of boundary -7.9999995 11503
# Empty ROOT file for bootstrap:  11518
# Value out of boundary -7.9999995 11549
# Empty ROOT file for bootstrap:  11550
# Empty ROOT file for bootstrap:  11552
# Value out of boundary -8.0 11599
# Processing fit_11600
# Value out of boundary -7.4416366 11615
# Empty ROOT file for bootstrap:  11619
# Value out of boundary -4.461769 11634
# Value out of boundary -7.1446757 11668
# Value out of boundary -7.9999995 11671
# Value out of boundary -8.0 11682
# Value out of boundary -4.5514474 11683
# Processing fit_11700
# Value out of boundary -4.3869596 11748
# Value out of boundary -7.8106914 11760
# Empty ROOT file for bootstrap:  11763
# Empty ROOT file for bootstrap:  11796
# Processing fit_11800
# Value out of boundary -7.9999976 11805
# Value out of boundary -7.9999995 11815
# Empty ROOT file for bootstrap:  11828
# Value out of boundary -7.9999995 11838
# Value out of boundary -4.5964727 11857
# Value out of boundary -4.2844105 11869
# Value out of boundary -6.0440784 11877
# Processing fit_11900
# Value out of boundary -7.9999995 11929
# Empty ROOT file for bootstrap:  11945
# Value out of boundary -4.1129375 11947
# Value out of boundary -4.4108515 11961
# Empty ROOT file for bootstrap:  11967
# Value out of boundary -4.7340784 11970
# Value out of boundary -7.460886 11974
# Empty ROOT file for bootstrap:  11979
# Value out of boundary -4.214238 11981
# Value out of boundary -7.999998 11992
# Processing fit_12000
# Value out of boundary -8.0 12017
# Empty ROOT file for bootstrap:  12036
# Value out of boundary -7.9999995 12038
# Value out of boundary -7.9999976 12043
# Empty ROOT file for bootstrap:  12058
# Empty ROOT file for bootstrap:  12059
# Value out of boundary -7.387639 12060
# Value out of boundary -5.422728 12085
# Value out of boundary -4.53106 12092
# Processing fit_12100
# Value out of boundary -5.4627275 12130
# Empty ROOT file for bootstrap:  12139
# Value out of boundary -7.9999976 12142
# Empty ROOT file for bootstrap:  12163
# Empty ROOT file for bootstrap:  12191
# Processing fit_12200
# Empty ROOT file for bootstrap:  12203
# Value out of boundary -7.263993 12212
# Empty ROOT file for bootstrap:  12222
# Value out of boundary -7.9999995 12258
# Value out of boundary -6.2363253 12262
# Empty ROOT file for bootstrap:  12287
# Value out of boundary -7.999999 12292
# Value out of boundary -6.2277665 12296
# Processing fit_12300
# Value out of boundary -4.2700067 12303
# Value out of boundary -5.8637915 12308
# Value out of boundary -6.9310923 12312
# Empty ROOT file for bootstrap:  12329
# Empty ROOT file for bootstrap:  12354
# Empty ROOT file for bootstrap:  12357
# Value out of boundary -5.2017097 12392
# Processing fit_12400
# Empty ROOT file for bootstrap:  12409
# Value out of boundary -5.2702055 12422
# Value out of boundary -7.9999995 12438
# Value out of boundary -6.9754105 12477
# Processing fit_12500
# Empty ROOT file for bootstrap:  12530
# Value out of boundary -8.0 12533
# Value out of boundary -5.9188795 12543
# Empty ROOT file for bootstrap:  12558
# Value out of boundary -6.2307096 12564
# Processing fit_12600
# Value out of boundary -8.0 12603
# Value out of boundary -5.8843274 12649
# Value out of boundary -8.0 12655
# Value out of boundary -7.999989 12657
# Empty ROOT file for bootstrap:  12671
# Empty ROOT file for bootstrap:  12672
# Empty ROOT file for bootstrap:  12676
# Empty ROOT file for bootstrap:  12698
# Empty ROOT file for bootstrap:  12699
# Processing fit_12700
# Value out of boundary -4.942201 12704
# Value out of boundary -4.046011 12727
# Empty ROOT file for bootstrap:  12739
# Empty ROOT file for bootstrap:  12742
# Value out of boundary -6.5118914 12764
# Value out of boundary -5.024573 12764
# Value out of boundary -4.7946744 12781
# Processing fit_12800
# Value out of boundary -7.2020726 12812
# Empty ROOT file for bootstrap:  12858
# Empty ROOT file for bootstrap:  12886
# Value out of boundary -8.0 12888
# Processing fit_12900
# Empty ROOT file for bootstrap:  12904
# Value out of boundary -7.999999 12959
# Value out of boundary -7.999999 12973
# Value out of boundary -8.0 12977
# Value out of boundary -7.9999967 12984
# Value out of boundary -7.0168552 12998
# Processing fit_13000
# Empty ROOT file for bootstrap:  13021
# Value out of boundary -5.71784 13034
# Value out of boundary -4.575713 13037
# Empty ROOT file for bootstrap:  13050
# Empty ROOT file for bootstrap:  13054
# Value out of boundary -7.1325693 13055
# Empty ROOT file for bootstrap:  13074
# Empty ROOT file for bootstrap:  13079
# Empty ROOT file for bootstrap:  13091
# Value out of boundary -8.0 13095
# Processing fit_13100
# Empty ROOT file for bootstrap:  13108
# Value out of boundary -7.999997 13131
# Value out of boundary -8.0 13132
# Empty ROOT file for bootstrap:  13136
# Value out of boundary -7.999999 13166
# Empty ROOT file for bootstrap:  13176
# Value out of boundary -6.7057376 13177
# Value out of boundary -5.8128176 13181
# Value out of boundary -5.217922 13185
# Processing fit_13200
# Empty ROOT file for bootstrap:  13207
# Empty ROOT file for bootstrap:  13240
# Empty ROOT file for bootstrap:  13277
# Empty ROOT file for bootstrap:  13280
# Value out of boundary -8.0 13285
# Value out of boundary -7.9999995 13290
# Value out of boundary -7.999943 13299
# Processing fit_13300
# Empty ROOT file for bootstrap:  13300
# Empty ROOT file for bootstrap:  13307
# Value out of boundary -4.900362 13320
# Value out of boundary -6.334326 13321
# Value out of boundary -4.230877 13342
# Value out of boundary -6.010802 13352
# Empty ROOT file for bootstrap:  13355
# Value out of boundary -6.8523483 13384
# Processing fit_13400
# Value out of boundary -6.2431364 13412
# Value out of boundary -4.037521 13437
# Value out of boundary -5.4647365 13458
# Value out of boundary -7.1902604 13469
# Value out of boundary -5.173253 13480
# Empty ROOT file for bootstrap:  13491
# Empty ROOT file for bootstrap:  13499
# Processing fit_13500
# Value out of boundary -8.0 13503
# Value out of boundary -7.812106 13528
# Empty ROOT file for bootstrap:  13534
# Value out of boundary -6.243949 13543
# Value out of boundary -7.823734 13548
# Value out of boundary -7.2746615 13590
# Empty ROOT file for bootstrap:  13598
# Processing fit_13600
# Value out of boundary -6.3601594 13617
# Empty ROOT file for bootstrap:  13619
# Empty ROOT file for bootstrap:  13629
# Value out of boundary -8.0 13635
# Empty ROOT file for bootstrap:  13637
# Empty ROOT file for bootstrap:  13667
# Value out of boundary -4.0128155 13668
# Value out of boundary -7.4201164 13687
# Empty ROOT file for bootstrap:  13689
# Processing fit_13700
# Empty ROOT file for bootstrap:  13708
# Value out of boundary -6.6431623 13720
# Empty ROOT file for bootstrap:  13751
# Value out of boundary -4.3995605 13754
# Value out of boundary -4.6487684 13777
# Value out of boundary -4.9584875 13780
# Value out of boundary -4.765045 13791
# Processing fit_13800
# Value out of boundary -8.0 13818
# Empty ROOT file for bootstrap:  13838
# Value out of boundary -7.9999995 13861
# Empty ROOT file for bootstrap:  13863
# Empty ROOT file for bootstrap:  13877
# Empty ROOT file for bootstrap:  13891
# Processing fit_13900
# Value out of boundary -7.999982 13934
# Value out of boundary -6.0188613 13941
# Empty ROOT file for bootstrap:  13982
# Empty ROOT file for bootstrap:  13997
# Processing fit_14000
# Value out of boundary -5.2629857 14007
# Value out of boundary -7.9999986 14032
# Empty ROOT file for bootstrap:  14050
# Empty ROOT file for bootstrap:  14059
# Empty ROOT file for bootstrap:  14060
# Value out of boundary -8.0 14079
# Empty ROOT file for bootstrap:  14099
# Processing fit_14100
# Value out of boundary -6.2702527 14113
# Empty ROOT file for bootstrap:  14114
# Value out of boundary -5.8372655 14140
# Empty ROOT file for bootstrap:  14150
# Empty ROOT file for bootstrap:  14166
# Value out of boundary -8.0 14168
# Value out of boundary -7.418875 14171
# Empty ROOT file for bootstrap:  14176
# Processing fit_14200
# Value out of boundary -6.7858877 14215
# Value out of boundary -6.752034 14224
# Empty ROOT file for bootstrap:  14225
# Empty ROOT file for bootstrap:  14230
# Empty ROOT file for bootstrap:  14235
# Value out of boundary -4.995864 14250
# Value out of boundary -6.606588 14291
# Value out of boundary -4.9656177 14293
# Value out of boundary -5.923458 14296
# Processing fit_14300
# Value out of boundary -4.007746 14318
# Empty ROOT file for bootstrap:  14323
# Value out of boundary -7.55321 14338
# Empty ROOT file for bootstrap:  14344
# Empty ROOT file for bootstrap:  14363
# Empty ROOT file for bootstrap:  14383
# Empty ROOT file for bootstrap:  14390
# Value out of boundary -4.1855326 14392
# Processing fit_14400
# Value out of boundary -7.9999986 14419
# Value out of boundary -4.256318 14442
# Value out of boundary -8.0 14455
# Value out of boundary -8.0 14493
# Processing fit_14500
# Value out of boundary -7.9999995 14506
# Empty ROOT file for bootstrap:  14516
# Empty ROOT file for bootstrap:  14571
# Value out of boundary -7.999999 14578
# Value out of boundary -6.38476 14582
# Processing fit_14600
# Empty ROOT file for bootstrap:  14636
# Empty ROOT file for bootstrap:  14641
# Value out of boundary -7.6779003 14644
# Value out of boundary -6.402022 14647
# Value out of boundary -7.9999986 14654
# Processing fit_14700
# Value out of boundary -5.150186 14705
# Value out of boundary -4.541703 14718
# Value out of boundary -4.407362 14728
# Value out of boundary -8.0 14732
# Empty ROOT file for bootstrap:  14735
# Empty ROOT file for bootstrap:  14737
# Value out of boundary -6.8115396 14739
# Empty ROOT file for bootstrap:  14752
# Value out of boundary -5.151031 14756
# Value out of boundary -4.4224033 14782
# Empty ROOT file for bootstrap:  14788
# Value out of boundary -6.0013185 14789
# Value out of boundary -7.6156507 14794
# Processing fit_14800
# Value out of boundary -8.0 14852
# Value out of boundary -8.0 14858
# Empty ROOT file for bootstrap:  14865
# Skipping fit_14889: Required scan files not found
# Processing fit_14900
# Empty ROOT file for bootstrap:  14907
# Value out of boundary -7.9999995 14910
# Value out of boundary -4.633062 14922
# Empty ROOT file for bootstrap:  14939
# Value out of boundary -4.5220037 14948
# Value out of boundary -8.0 14957
# Value out of boundary -8.0 14974
# Empty ROOT file for bootstrap:  14988
# Processing fit_15000
# Empty ROOT file for bootstrap:  15004
# Value out of boundary -8.0 15015
# Value out of boundary -5.8773685 15035
# Empty ROOT file for bootstrap:  15068
# Value out of boundary -6.591566 15089
# Processing fit_15100
# Value out of boundary -8.0 15103
# Value out of boundary -7.999998 15119
# Value out of boundary -7.9999995 15133
# Value out of boundary -6.3974104 15143
# Value out of boundary -5.547637 15148
# Empty ROOT file for bootstrap:  15172
# Value out of boundary -6.0117106 15193
# Processing fit_15200
# Value out of boundary -4.8695846 15200
# Value out of boundary -8.0 15203
# Value out of boundary -4.312199 15276
# Value out of boundary -8.0 15286
# Processing fit_15300
# Empty ROOT file for bootstrap:  15304
# Value out of boundary -5.6129975 15325
# Empty ROOT file for bootstrap:  15329
# Empty ROOT file for bootstrap:  15350
# Value out of boundary -4.24072 15358
# Value out of boundary -4.0401635 15368
# Value out of boundary -5.279506 15387
# Processing fit_15400
# Empty ROOT file for bootstrap:  15407
# Empty ROOT file for bootstrap:  15432
# Empty ROOT file for bootstrap:  15473
# Value out of boundary -8.0 15484
# Value out of boundary -7.9999995 15496
# Value out of boundary -7.9999995 15498
# Processing fit_15500
# Value out of boundary -7.264036 15512
# Value out of boundary -8.0 15513
# Value out of boundary -4.763478 15525
# Value out of boundary -8.0 15529
# Value out of boundary -7.9999995 15591
# Value out of boundary -8.0 15594
# Processing fit_15600
# Empty ROOT file for bootstrap:  15606
# Value out of boundary -4.413668 15635
# Empty ROOT file for bootstrap:  15636
# Value out of boundary -4.191807 15654
# Empty ROOT file for bootstrap:  15667
# Value out of boundary -4.735699 15672
# Processing fit_15700
# Value out of boundary -7.9999986 15753
# Empty ROOT file for bootstrap:  15759
# Empty ROOT file for bootstrap:  15771
# Processing fit_15800
# Value out of boundary -7.889864 15804
# Value out of boundary -8.0 15808
# Value out of boundary -6.0161767 15809
# Value out of boundary -7.043748 15820
# Value out of boundary -8.0 15824
# Value out of boundary -4.0026517 15842
# Value out of boundary -5.531583 15844
# Value out of boundary -6.353738 15851
# Value out of boundary -7.999999 15864
# Empty ROOT file for bootstrap:  15867
# Value out of boundary -5.260127 15898
# Empty ROOT file for bootstrap:  15899
# Processing fit_15900
# Empty ROOT file for bootstrap:  15909
# Empty ROOT file for bootstrap:  15941
# Empty ROOT file for bootstrap:  15950
# Value out of boundary -5.8650184 15977
# Value out of boundary -6.034999 15999
# Processing fit_16000
# Value out of boundary -4.6369696 16000
# Value out of boundary -4.9723144 16024
# Value out of boundary -5.853805 16026
# Value out of boundary -6.15608 16045
# Value out of boundary -4.310383 16050
# Value out of boundary -7.999998 16053
# Value out of boundary -4.9096885 16069
# Value out of boundary -4.5655622 16075
# Processing fit_16100
# Empty ROOT file for bootstrap:  16126
# Value out of boundary -4.10303 16148
# Value out of boundary -7.682481 16161
# Empty ROOT file for bootstrap:  16167
# Value out of boundary -7.9999986 16190
# Processing fit_16200
# Empty ROOT file for bootstrap:  16214
# Value out of boundary -5.8938637 16240
# Value out of boundary -4.332274 16241
# Empty ROOT file for bootstrap:  16245
# Value out of boundary -7.9999995 16258
# Empty ROOT file for bootstrap:  16260
# Value out of boundary -8.0 16292
# Value out of boundary -4.7337017 16294
# Processing fit_16300
# Value out of boundary -4.664658 16309
# Empty ROOT file for bootstrap:  16316
# Value out of boundary -6.546177 16327
# Empty ROOT file for bootstrap:  16341
# Value out of boundary -7.999998 16347
# Empty ROOT file for bootstrap:  16362
# Value out of boundary -7.9999986 16382
# Processing fit_16400
# Empty ROOT file for bootstrap:  16416
# Value out of boundary -6.101193 16422
# Value out of boundary -4.2221394 16428
# Value out of boundary -5.381647 16431
# Value out of boundary -4.7595835 16473
# Value out of boundary -7.9999986 16494
# Processing fit_16500
# Value out of boundary -7.9999976 16510
# Value out of boundary -6.134783 16519
# Empty ROOT file for bootstrap:  16545
# Empty ROOT file for bootstrap:  16546
# Value out of boundary -8.0 16557
# Value out of boundary -8.0 16566
# Value out of boundary -4.205331 16590
# Processing fit_16600
# Empty ROOT file for bootstrap:  16628
# Value out of boundary -7.999998 16655
# Empty ROOT file for bootstrap:  16660
# Value out of boundary -7.74718 16661
# Empty ROOT file for bootstrap:  16665
# Empty ROOT file for bootstrap:  16666
# Empty ROOT file for bootstrap:  16678
# Value out of boundary -6.231933 16679
# Processing fit_16700
# Empty ROOT file for bootstrap:  16716
# Empty ROOT file for bootstrap:  16729
# Value out of boundary -6.326212 16760
# Value out of boundary -7.889028 16765
# Value out of boundary -7.9999967 16776
# Value out of boundary -6.6072 16787
# Processing fit_16800
# Empty ROOT file for bootstrap:  16806
# Empty ROOT file for bootstrap:  16813
# Empty ROOT file for bootstrap:  16836
# Value out of boundary -4.8776636 16875
# Value out of boundary -7.9999995 16887
# Empty ROOT file for bootstrap:  16890
# Processing fit_16900
# Empty ROOT file for bootstrap:  16900
# Empty ROOT file for bootstrap:  16902
# Value out of boundary -4.775478 16911
# Empty ROOT file for bootstrap:  16913
# Value out of boundary -4.1344213 16917
# Empty ROOT file for bootstrap:  16931
# Empty ROOT file for bootstrap:  16943
# Value out of boundary -7.999999 16947
# Value out of boundary -4.085935 16954
# Value out of boundary -4.3361387 16956
# Value out of boundary -7.885836 16972
# Empty ROOT file for bootstrap:  16992
# Value out of boundary -6.838879 16997
# Processing fit_17000
# Value out of boundary -7.929587 17008
# Value out of boundary -4.8043303 17017
# Value out of boundary -8.0 17042
# Value out of boundary -8.0 17049
# Value out of boundary -7.999998 17055
# Value out of boundary -8.0 17059
# Value out of boundary -7.497829 17074
# Empty ROOT file for bootstrap:  17084
# Value out of boundary -4.7756624 17095
# Processing fit_17100
# Empty ROOT file for bootstrap:  17100
# Value out of boundary -5.841335 17103
# Empty ROOT file for bootstrap:  17104
# Value out of boundary -6.0711465 17147
# Value out of boundary -5.8672953 17167
# Value out of boundary -7.9231577 17170
# Value out of boundary -4.536169 17177
# Value out of boundary -4.584769 17178
# Value out of boundary -5.255817 17183
# Value out of boundary -6.2334304 17190
# Value out of boundary -4.436621 17194
# Processing fit_17200
# Value out of boundary -4.187875 17204
# Value out of boundary -5.662808 17206
# Empty ROOT file for bootstrap:  17207
# Value out of boundary -5.715409 17213
# Empty ROOT file for bootstrap:  17217
# Empty ROOT file for bootstrap:  17226
# Value out of boundary -6.419887 17250
# Value out of boundary -7.9999976 17257
# Value out of boundary -5.295196 17268
# Value out of boundary -8.0 17270
# Value out of boundary -8.0 17297
# Empty ROOT file for bootstrap:  17299
# Processing fit_17300
# Value out of boundary -5.32263 17338
# Value out of boundary -7.9999995 17340
# Value out of boundary -8.0 17341
# Empty ROOT file for bootstrap:  17342
# Empty ROOT file for bootstrap:  17360
# Value out of boundary -8.0 17392
# Value out of boundary -8.0 17393
# Processing fit_17400
# ...
# Skipping fit_16519 with -6.134782791137695: Outlier found
# Empty ROOT file for bootstrap:  16545
# Empty ROOT file for bootstrap:  16545
# Empty ROOT file for bootstrap:  16546
# Empty ROOT file for bootstrap:  16546
# Skipping fit_16557 with -8.0: Outlier found
# Skipping fit_16566 with -8.0: Outlier found
# Value out of boundary -4.205331 16590
# Processing fit_16600
# Empty ROOT file for bootstrap:  16628
# Empty ROOT file for bootstrap:  16628
# Skipping fit_16655 with -7.999998092651367: Outlier found
# Empty ROOT file for bootstrap:  16660
# Empty ROOT file for bootstrap:  16660
# Skipping fit_16661 with -7.747179985046387: Outlier found
# Empty ROOT file for bootstrap:  16665
# Empty ROOT file for bootstrap:  16665
# Empty ROOT file for bootstrap:  16666
# Empty ROOT file for bootstrap:  16666
# Empty ROOT file for bootstrap:  16678
# Empty ROOT file for bootstrap:  16678
# Skipping fit_16679 with -6.231933116912842: Outlier found
# Processing fit_16700
# Empty ROOT file for bootstrap:  16716
# Empty ROOT file for bootstrap:  16716
# Empty ROOT file for bootstrap:  16729
# Empty ROOT file for bootstrap:  16729
# Skipping fit_16757 with 7.3794846534729: Outlier found
# Skipping fit_16760 with -6.326211929321289: Outlier found
# Skipping fit_16765 with -7.889028072357178: Outlier found
# Skipping fit_16776 with -7.999996662139893: Outlier found
# Skipping fit_16787 with -6.6072001457214355: Outlier found
# Processing fit_16800
# Empty ROOT file for bootstrap:  16806
# Empty ROOT file for bootstrap:  16806
# Empty ROOT file for bootstrap:  16813
# Empty ROOT file for bootstrap:  16813
# Empty ROOT file for bootstrap:  16836
# Empty ROOT file for bootstrap:  16836
# Value out of boundary -4.8776636 16875
# Skipping fit_16887 with -7.999999523162842: Outlier found
# Empty ROOT file for bootstrap:  16890
# Empty ROOT file for bootstrap:  16890
# Processing fit_16900
# Empty ROOT file for bootstrap:  16900
# Empty ROOT file for bootstrap:  16900
# Empty ROOT file for bootstrap:  16902
# Empty ROOT file for bootstrap:  16902
# Value out of boundary -4.775478 16911
# Empty ROOT file for bootstrap:  16913
# Empty ROOT file for bootstrap:  16913
# Value out of boundary -4.1344213 16917
# Empty ROOT file for bootstrap:  16931
# Empty ROOT file for bootstrap:  16931
# Empty ROOT file for bootstrap:  16943
# Empty ROOT file for bootstrap:  16943
# Skipping fit_16947 with -7.999999046325684: Outlier found
# Value out of boundary -4.085935 16954
# Value out of boundary -4.3361387 16956
# Skipping fit_16972 with -7.885836124420166: Outlier found
# Empty ROOT file for bootstrap:  16992
# Empty ROOT file for bootstrap:  16992
# Skipping fit_16997 with -6.838879108428955: Outlier found
# Processing fit_17000
# Skipping fit_17008 with -7.929586887359619: Outlier found
# Value out of boundary -4.8043303 17017
# Skipping fit_17042 with -8.0: Outlier found
# Skipping fit_17049 with -8.0: Outlier found
# Skipping fit_17055 with -7.999998092651367: Outlier found
# Skipping fit_17059 with -8.0: Outlier found
# Skipping fit_17074 with -7.497828960418701: Outlier found
# Empty ROOT file for bootstrap:  17084
# Empty ROOT file for bootstrap:  17084
# Value out of boundary -4.7756624 17095
# Processing fit_17100
# Empty ROOT file for bootstrap:  17100
# Empty ROOT file for bootstrap:  17100
# Skipping fit_17103 with -5.841334819793701: Outlier found
# Empty ROOT file for bootstrap:  17104
# Empty ROOT file for bootstrap:  17104
# Skipping fit_17147 with -6.071146488189697: Outlier found
# Skipping fit_17167 with -5.867295265197754: Outlier found
# Skipping fit_17170 with -7.923157691955566: Outlier found
# Value out of boundary -4.536169 17177
# Value out of boundary -4.584769 17178
# Skipping fit_17183 with -5.25581693649292: Outlier found
# Skipping fit_17190 with -6.2334303855896: Outlier found
# Value out of boundary -4.436621 17194
# Processing fit_17200
# Value out of boundary -4.187875 17204
# Skipping fit_17206 with -5.662807941436768: Outlier found
# Empty ROOT file for bootstrap:  17207
# Empty ROOT file for bootstrap:  17207
# Skipping fit_17213 with -5.715408802032471: Outlier found
# Empty ROOT file for bootstrap:  17217
# Empty ROOT file for bootstrap:  17217
# Empty ROOT file for bootstrap:  17226
# Empty ROOT file for bootstrap:  17226
# Skipping fit_17250 with -6.419887065887451: Outlier found
# Skipping fit_17257 with -7.999997615814209: Outlier found
# Skipping fit_17268 with -5.295196056365967: Outlier found
# Skipping fit_17270 with -8.0: Outlier found
# Skipping fit_17297 with -8.0: Outlier found
# Empty ROOT file for bootstrap:  17299
# Empty ROOT file for bootstrap:  17299
# Processing fit_17300
# Skipping fit_17338 with -5.322629928588867: Outlier found
# Skipping fit_17340 with -7.999999523162842: Outlier found
# Skipping fit_17341 with -8.0: Outlier found
# Empty ROOT file for bootstrap:  17342
# Empty ROOT file for bootstrap:  17342
# Empty ROOT file for bootstrap:  17360
# Empty ROOT file for bootstrap:  17360
# Skipping fit_17392 with -8.0: Outlier found
# Skipping fit_17393 with -8.0: Outlier found
# Processing fit_17400
# Skipping fit_17413 with -7.999999523162842: Outlier found
# Skipping fit_17436 with -8.0: Outlier found
# Skipping fit_17456 with -8.0: Outlier found
# Empty ROOT file for bootstrap:  17459
# Empty ROOT file for bootstrap:  17459
# Skipping fit_17495 with -8.0: Outlier found
# Processing fit_17500
# Value out of boundary -4.99593 17523
# Skipping fit_17551 with -8.0: Outlier found
# Skipping fit_17563 with 7.328213214874268: Outlier found
# Empty ROOT file for bootstrap:  17591
# Empty ROOT file for bootstrap:  17591
# Skipping fit_17597 with -8.0: Outlier found
# Processing fit_17600
# Skipping fit_17607 with -7.13991117477417: Outlier found
# Skipping fit_17610 with -8.0: Outlier found
# Skipping fit_17621 with -6.945677757263184: Outlier found
# Empty ROOT file for bootstrap:  17622
# Empty ROOT file for bootstrap:  17622
# Empty ROOT file for bootstrap:  17653
# Empty ROOT file for bootstrap:  17653
# Empty ROOT file for bootstrap:  17656
# Empty ROOT file for bootstrap:  17656
# Skipping fit_17663 with -7.999999046325684: Outlier found
# Skipping fit_17667 with -8.0: Outlier found
# Skipping fit_17668 with -8.0: Outlier found
# Empty ROOT file for bootstrap:  17671
# Empty ROOT file for bootstrap:  17671
# Processing fit_17700
# Empty ROOT file for bootstrap:  17709
# Empty ROOT file for bootstrap:  17709
# Skipping fit_17737 with -7.999999523162842: Outlier found
# Empty ROOT file for bootstrap:  17740
# Empty ROOT file for bootstrap:  17740
# Skipping fit_17743 with -5.170926570892334: Outlier found
# Empty ROOT file for bootstrap:  17748
# Empty ROOT file for bootstrap:  17748
# Skipping fit_17751 with -5.606389045715332: Outlier found
# Skipping fit_17759 with -7.999999046325684: Outlier found
# Value out of boundary -4.140715 17769
# Empty ROOT file for bootstrap:  17781
# Empty ROOT file for bootstrap:  17781
# Empty ROOT file for bootstrap:  17792
# Empty ROOT file for bootstrap:  17792
# Processing fit_17800
# Empty ROOT file for bootstrap:  17809
# Empty ROOT file for bootstrap:  17809
# Skipping fit_17817 with -7.999996185302734: Outlier found
# Skipping fit_17834 with -7.651939392089844: Outlier found
# Skipping fit_17837 with -6.512935161590576: Outlier found
# Skipping fit_17839 with -6.9481587409973145: Outlier found
# Skipping fit_17848 with -8.0: Outlier found
# Value out of boundary -4.6688194 17858
# Skipping fit_17859 with -8.0: Outlier found
# Skipping fit_17867 with -8.0: Outlier found
# Skipping fit_17871 with -7.999999046325684: Outlier found
# Skipping fit_17886 with -8.0: Outlier found
# Skipping fit_17887 with -7.9999871253967285: Outlier found
# Skipping fit_17896 with -6.169518947601318: Outlier found
# Processing fit_17900
# Value out of boundary -4.48222 17925
# Skipping fit_17931 with -5.780501365661621: Outlier found
# Empty ROOT file for bootstrap:  17937
# Empty ROOT file for bootstrap:  17937
# Skipping fit_17944 with -8.0: Outlier found
# Empty ROOT file for bootstrap:  17968
# Empty ROOT file for bootstrap:  17968
# Skipping fit_17978 with -7.999999523162842: Outlier found
# Processing fit_18000
# Processing fit_18100
# Skipping fit_18112 with -6.257531642913818: Outlier found
# Skipping fit_18126 with -7.999998092651367: Outlier found
# Empty ROOT file for bootstrap:  18140
# Empty ROOT file for bootstrap:  18140
# Skipping fit_18144 with -8.0: Outlier found
# Empty ROOT file for bootstrap:  18153
# Empty ROOT file for bootstrap:  18153
# Skipping fit_18171 with -6.419796466827393: Outlier found
# Skipping fit_18174 with -6.72465705871582: Outlier found
# Processing fit_18200
# Value out of boundary -4.9895687 18204
# Value out of boundary -4.602391 18215
# Value out of boundary -4.309516 18231
# Value out of boundary -4.413228 18236
# Skipping fit_18246 with -8.0: Outlier found
# Skipping fit_18249 with -6.549637317657471: Outlier found
# Processing fit_18300
# Empty ROOT file for bootstrap:  18304
# Empty ROOT file for bootstrap:  18304
# Empty ROOT file for bootstrap:  18314
# Empty ROOT file for bootstrap:  18314
# Empty ROOT file for bootstrap:  18346
# Empty ROOT file for bootstrap:  18346
# Skipping fit_18379 with -8.0: Outlier found
# Skipping fit_18385 with -8.0: Outlier found
# Empty ROOT file for bootstrap:  18386
# Empty ROOT file for bootstrap:  18386
# Skipping fit_18388 with -7.999998569488525: Outlier found
# Skipping fit_18392 with -8.0: Outlier found
# Processing fit_18400
# Value out of boundary -4.2358737 18406
# Value out of boundary -4.919419 18429
# Skipping fit_18478 with -8.0: Outlier found
# Skipping fit_18479 with -8.0: Outlier found
# Processing fit_18500
# Skipping fit_18500 with -7.725039958953857: Outlier found
# Skipping fit_18501 with -6.520929336547852: Outlier found
# Empty ROOT file for bootstrap:  18510
# Empty ROOT file for bootstrap:  18510
# Skipping fit_18521 with -7.464577674865723: Outlier found
# Skipping fit_18536 with -7.999999523162842: Outlier found
# Skipping fit_18538 with -8.0: Outlier found
# Skipping fit_18556 with -7.999997138977051: Outlier found
# Value out of boundary -4.1051493 18567
# Skipping fit_18577 with -7.999999523162842: Outlier found
# Empty ROOT file for bootstrap:  18592
# Empty ROOT file for bootstrap:  18592
# Empty ROOT file for bootstrap:  18598
# Empty ROOT file for bootstrap:  18598
# Processing fit_18600
# Skipping fit_18604 with -6.8301801681518555: Outlier found
# Empty ROOT file for bootstrap:  18628
# Empty ROOT file for bootstrap:  18628
# Value out of boundary -4.0412173 18640
# Empty ROOT file for bootstrap:  18657
# Empty ROOT file for bootstrap:  18657
# Skipping fit_18676 with -6.203110694885254: Outlier found
# Empty ROOT file for bootstrap:  18680
# Empty ROOT file for bootstrap:  18680
# Processing fit_18700
# Skipping fit_18708 with -6.008222579956055: Outlier found
# Skipping fit_18709 with -6.078301906585693: Outlier found
# Skipping fit_18714 with -7.999998092651367: Outlier found
# Value out of boundary -4.6217504 18731
# Skipping fit_18771 with -8.0: Outlier found
# Processing fit_18800
# Skipping fit_18813 with -5.5838942527771: Outlier found
# Skipping fit_18818 with -7.084596633911133: Outlier found
# Value out of boundary -4.539682 18837
# Skipping fit_18869 with -6.447993278503418: Outlier found
# Skipping fit_18888 with -5.906370162963867: Outlier found
# Skipping fit_18896 with -8.0: Outlier found
# Processing fit_18900
# Empty ROOT file for bootstrap:  18900
# Empty ROOT file for bootstrap:  18900
# Empty ROOT file for bootstrap:  18910
# Empty ROOT file for bootstrap:  18910
# Skipping fit_18916 with -5.878802299499512: Outlier found
# Empty ROOT file for bootstrap:  18956
# Empty ROOT file for bootstrap:  18956
# Value out of boundary -4.3454676 18960
# Empty ROOT file for bootstrap:  18978
# Empty ROOT file for bootstrap:  18978
# Skipping fit_18989 with -7.999999523162842: Outlier found
# Processing fit_19000
# Processing fit_19100
# Empty ROOT file for bootstrap:  19111
# Empty ROOT file for bootstrap:  19111
# Skipping fit_19137 with -5.218161582946777: Outlier found
# Skipping fit_19139 with -5.499656677246094: Outlier found
# Skipping fit_19149 with -6.16156005859375: Outlier found
# Processing fit_19200
# Value out of boundary -4.6030016 19210
# Skipping fit_19232 with -8.0: Outlier found
# Value out of boundary -4.8513803 19237
# Skipping fit_19254 with -7.999998092651367: Outlier found
# Value out of boundary -4.770376 19276
# Empty ROOT file for bootstrap:  19281
# Empty ROOT file for bootstrap:  19281
# Empty ROOT file for bootstrap:  19296
# Empty ROOT file for bootstrap:  19296
# Processing fit_19300
# Skipping fit_19302 with -7.746268272399902: Outlier found
# Value out of boundary -4.0823965 19307
# Skipping fit_19331 with -5.7153401374816895: Outlier found
# Value out of boundary -4.125081 19336
# Skipping fit_19355 with -5.709859848022461: Outlier found
# Empty ROOT file for bootstrap:  19357
# Empty ROOT file for bootstrap:  19357
# Skipping fit_19361 with -5.256309986114502: Outlier found
# Empty ROOT file for bootstrap:  19375
# Empty ROOT file for bootstrap:  19375
# Empty ROOT file for bootstrap:  19376
# Empty ROOT file for bootstrap:  19376
# Empty ROOT file for bootstrap:  19379
# Empty ROOT file for bootstrap:  19379
# Skipping fit_19396 with -7.999999523162842: Outlier found
# Processing fit_19400
# Empty ROOT file for bootstrap:  19400
# Empty ROOT file for bootstrap:  19400
# Value out of boundary -4.8665357 19409
# Empty ROOT file for bootstrap:  19422
# Empty ROOT file for bootstrap:  19422
# Empty ROOT file for bootstrap:  19434
# Empty ROOT file for bootstrap:  19434
# Skipping fit_19443 with -5.552553176879883: Outlier found
# Skipping fit_19495 with -5.8303422927856445: Outlier found
# Empty ROOT file for bootstrap:  19496
# Empty ROOT file for bootstrap:  19496
# Processing fit_19500
# Skipping fit_19504 with -7.999998569488525: Outlier found
# Skipping fit_19506 with -7.999999523162842: Outlier found
# Skipping fit_19515 with -8.0: Outlier found
# Empty ROOT file for bootstrap:  19520
# Empty ROOT file for bootstrap:  19520
# Skipping fit_19535 with -7.9933929443359375: Outlier found
# Skipping fit_19536 with -7.927194118499756: Outlier found
# Value out of boundary -5.13822 19547
# Skipping fit_19566 with -5.3674702644348145: Outlier found
# Skipping fit_19568 with -5.926733016967773: Outlier found
# Skipping fit_19588 with -7.999998092651367: Outlier found
# Skipping fit_19593 with -7.999999523162842: Outlier found
# Processing fit_19600
# Skipping fit_19610 with -7.8221564292907715: Outlier found
# Value out of boundary -4.5554967 19627
# Skipping fit_19645 with -5.855124473571777: Outlier found
# Empty ROOT file for bootstrap:  19649
# Empty ROOT file for bootstrap:  19649
# Empty ROOT file for bootstrap:  19658
# Empty ROOT file for bootstrap:  19658
# Value out of boundary -4.799357 19661
# Skipping fit_19682 with -6.762614727020264: Outlier found
# Empty ROOT file for bootstrap:  19684
# Empty ROOT file for bootstrap:  19684
# Processing fit_19700
# Skipping fit_19724 with -8.0: Outlier found
# Skipping fit_19725 with -8.0: Outlier found
# Skipping fit_19727 with -6.225175857543945: Outlier found
# Empty ROOT file for bootstrap:  19728
# Empty ROOT file for bootstrap:  19728
# Skipping fit_19734 with -6.217423915863037: Outlier found
# Value out of boundary -4.054393 19735
# Empty ROOT file for bootstrap:  19742
# Empty ROOT file for bootstrap:  19742
# Skipping fit_19752 with -8.0: Outlier found
# Empty ROOT file for bootstrap:  19754
# Empty ROOT file for bootstrap:  19754
# Processing fit_19800
# Skipping fit_19801 with 7.448976516723633: Outlier found
# Value out of boundary -4.646293 19807
# Skipping fit_19834 with -8.0: Outlier found
# Skipping fit_19852 with -7.999999046325684: Outlier found
# Value out of boundary -4.916147 19853
# Skipping fit_19866 with -5.570429801940918: Outlier found
# Empty ROOT file for bootstrap:  19868
# Empty ROOT file for bootstrap:  19868
# Empty ROOT file for bootstrap:  19883
# Empty ROOT file for bootstrap:  19883
# Processing fit_19900
# Skipping fit_19902 with -7.766790866851807: Outlier found
# Value out of boundary -4.12758 19912
# Skipping fit_19917 with -8.0: Outlier found
# Skipping fit_19935 with -7.429321765899658: Outlier found
# Empty ROOT file for bootstrap:  19939
# Empty ROOT file for bootstrap:  19939
# Skipping fit_19941 with -6.514153003692627: Outlier found
# Skipping fit_19952 with -8.0: Outlier found
# Skipping fit_19968 with -7.745415687561035: Outlier found
# Value out of boundary -4.229638 19972
# Skipping fit_19988 with -8.0: Outlier found

# %%
# Load DPhiJ0J1 toys
variable = "DPhiJ0J1"
# sample_dir = '/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2025_06_12/intermediateRun3/finalfits'
sample_dir = '/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2025_09_06_powheg/finalfits'
main_dir = os.path.join(sample_dir, variable, "Combine", f"runFits_{variable}")
toyDir = os.path.join(main_dir, "toyFit")

poi_list_DPhiJ0J1 = ["r_DPhiJ0J1_m3p1416_m2p0944", "r_DPhiJ0J1_m2p0944_m1p0472", "r_DPhiJ0J1_m1p0472_0p0", "r_DPhiJ0J1_0p0_1p0472", "r_DPhiJ0J1_1p0472_2p0944", "r_DPhiJ0J1_2p0944_3p1416"]

pois_untrimmed_DPhiJ0J1 = create_json_untrimmed(variable, toyDir, poi_list_DPhiJ0J1)
pois_DPhiJ0J1 = create_json_trimmed(variable, toyDir, pois_untrimmed_DPhiJ0J1, poi_list_DPhiJ0J1, subfolder_=f"SL_{variable}")

plot_all_individual_correlation(pois_untrimmed_DPhiJ0J1, poi_list_DPhiJ0J1, variable)

# %%
# Load rapidity toys
variable = "rapidity"
# sample_dir = '/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2025_06_12/intermediateRun3/finalfits'
sample_dir = '/pnfs/psi.ch/cms/trivcat/store/user/niharrin/ntuples/midRun3/samples/2025_09_06_powheg/finalfits'
main_dir = os.path.join(sample_dir, variable, "Combine", f"runFits_{variable}")
toyDir = os.path.join(main_dir, "toyFit")

poi_list_rapidity = ["r_YH_0p0_0p15", "r_YH_0p15_0p3", "r_YH_0p3_0p6", "r_YH_0p6_0p9", "r_YH_0p9_2p5"]

pois_untrimmed_rapidity = create_json_untrimmed(variable, toyDir, poi_list_rapidity)
pois_rapidity = create_json_trimmed(variable, toyDir, pois_untrimmed_rapidity, poi_list_rapidity, subfolder_=f"SL_{variable}")

plot_all_individual_correlation(pois_untrimmed_rapidity, poi_list_rapidity, variable)
# Out:
# Trimming values:  -2.912816328953988 5.083735832786939

# %%
df_PTH = pd.DataFrame(pois_PTH)
df_NJ = pd.DataFrame(pois_NJ)
df_PTJ0 = pd.DataFrame(pois_PTJ0)
# df_DPhiJ0J1 = pd.DataFrame(pois_DPhiJ0J1)
df_rapidity = pd.DataFrame(pois_rapidity)
# print(df_PTH)
# print(df_NJ)
print(df_PTJ0)
# print(df_DPhiJ0J1)
# print(df_rapidity)
# Out:
#        r_PTJ0_0p0_30p0  r_PTJ0_30p0_75p0  r_PTJ0_75p0_120p0  \
# 0             0.732738          1.075125           1.312504
# 1             1.468491          0.317425          -0.561540
# 2          -999.000000       -999.000000        -999.000000
# 3             0.904880          1.776465           1.428310
# 4             0.253824          2.846097           1.188133
# ...                ...               ...                ...
# 19995         0.724507          0.751987           2.179901
# 19996         0.584719          0.093970           1.594411
# 19997         1.548044          0.608474           2.517668
# 19998         1.591447         -0.040112           0.499703
# 19999         0.588628          1.747372           1.972355
#
#        r_PTJ0_120p0_200p0  r_PTJ0_200p0_10000p0
# 0                1.674949              2.132406
# 1                2.046980             -1.194650
# 2             -999.000000           -999.000000
# 3                0.977205              3.310657
# 4                1.818397             -1.622304
# ...                   ...                   ...
# 19995            2.181245              1.391920
# 19996            2.007523             -0.234103
# 19997            1.357446              1.821606
# 19998            1.920561              1.730339
# 19999            0.058128              3.055770
#
# [20000 rows x 5 columns]

# %%
# --- Step 1: Identify rows WITHOUT -999 in either DataFrame ---
# # Mask for df_PTH (True = valid, False = -999)
mask_pth = (df_PTH != -999).all(axis=1)

# # Mask for df_NJ (True = valid, False = -999)
mask_nj = (df_NJ != -999).all(axis=1)

# # Mask for df_PTJ0 (True = valid, False = -999)
mask_ptj0 = (df_PTJ0 != -999).all(axis=1)

# # Mask for df_DPhiJ0J1 (True = valid, False = -999)
# mask_DPhiJ0J1 = (df_DPhiJ0J1 != -999).all(axis=1)

# # Mask for df_rapidity (True = valid, False = -999)
mask_rapidity = (df_rapidity != -999).all(axis=1)

# Combined mask (keep only rows valid in BOTH DataFrames)
# valid_rows = mask_pth & mask_nj & mask_ptj0 & mask_DPhiJ0J1 & mask_rapidity
valid_rows = mask_pth & mask_nj & mask_rapidity & mask_ptj0

# --- Step 2: Filter DataFrames ---
df_PTH_clean = df_PTH[valid_rows]
df_NJ_clean = df_NJ[valid_rows]
df_PTJ0_clean = df_PTJ0[valid_rows]
# df_DPhiJ0J1_clean = df_DPhiJ0J1[valid_rows]
df_rapidity_clean = df_rapidity[valid_rows]

# --- Step 3: Compute Correlation Matrix ---
# Combine columns (now aligned and cleaned)
# df_combined = pd.concat([df_PTH_clean, df_DPhiJ0J1_clean, df_NJ_clean, df_PTJ0_clean, df_rapidity_clean], axis=1)
df_combined = pd.concat([df_PTH_clean, df_NJ_clean, df_rapidity_clean, df_PTJ0_clean], axis=1)
# df_combined = pd.concat([df_PTH_clean, df_PTJ0_clean, df_NJ_clean], axis=1)

# Calculate full correlation matrix
corr_matrix = df_combined.corr()

# # Extract cross-correlations (PTH vs. NJ bins)
# pth_cols = df_PTH.columns
# nj_cols = df_NJ.columns
# ptj0_cols = df_PTJ0.columns
# print(ptj0_cols)
# cross_corr = corr_matrix.loc[pth_cols, nj_cols, ptj0_cols]

# print("Correlation Matrix (Excluding Rows with -999):")
# print(cross_corr)

# %%
# 1️⃣ Define your stops and RGB values
stops = [0.0, 0.5, 1.0]
red   = [0.992, 1.0, 0.110]
green = [0.749, 1.0, 0.196]
blue  = [0.106, 1.0, 0.867]

# 2️⃣ Build the color dictionary
cdict = {
    'red':   [(stops[i], red[i], red[i]) for i in range(len(stops))],
    'green': [(stops[i], green[i], green[i]) for i in range(len(stops))],
    'blue':  [(stops[i], blue[i], blue[i]) for i in range(len(stops))]
}

# 3️⃣ Create the colormap
custom_cmap = LinearSegmentedColormap('gradient_8289', cdict)

# %%
modified_corr_matrix = corr_matrix.copy()
modified_corr_matrix = modified_corr_matrix.where(abs(modified_corr_matrix) >= 0.01, 0)  # Set values greater than 0.1 to 0

modified_corr_matrix = modified_corr_matrix.rename(index=translation, columns=translation)

plt.figure(figsize=(28, 14))
plt.style.use(hep.style.CMS)
hep.cms.label('Preliminary', data=False, lumi=9.5, com=13.6)
ax = sns.heatmap(modified_corr_matrix, annot=True, cmap=custom_cmap, vmin=-0.5, vmax=0.5, annot_kws={"size": 16}, linewidths=0.0, linecolor='black', fmt=".2f")

ax.tick_params(
    axis='both',      # apply to both axes
    which='both',     # apply to both major and minor ticks
    bottom=False,     # remove bottom ticks
    top=False,        # remove top ticks
    left=False,       # remove left ticks
    right=False,      # remove right ticks
    labelbottom=True, # keep labels if you want
    labelleft=True    # keep labels if you want
)

# Get the number of rows and columns
n_rows, n_cols = modified_corr_matrix.shape

# Add rectangle around the whole heatmap to complete the outer box
rect = Rectangle(
    (0, 0),          # bottom left corner
    width=n_cols,    # number of columns
    height=n_rows,   # number of rows
    fill=False,      # no fill, just the edge
    edgecolor='black',
    linewidth=1.5
)
ax.add_patch(rect)

# Define group boundaries (between variable blocks)
group_boundaries = [8, 12, 17, 23]  # Example indices between variable blocks # 8, 14, 18, 23

# Draw thick lines between groups
for boundary in group_boundaries:
    ax.axhline(boundary, color='black', linewidth=1, linestyle='--')
    ax.axvline(boundary, color='black', linewidth=1, linestyle='--')

plt.savefig(os.path.join(plot_dir, "correlation_matrix.pdf"), bbox_inches='tight')
plt.savefig(os.path.join(plot_dir, "correlation_matrix.png"), bbox_inches='tight')

# plt.close()

# %%
def plot_matrix(matrix, boundary, filename):
    plt.figure(figsize=(14, 8))
    plt.style.use(hep.style.CMS)
    hep.cms.label('Preliminary', data=False, lumi=9.5, com=13.6)
    ax = sns.heatmap(matrix, annot=True, cmap=custom_cmap, vmin=-0.5, vmax=0.5, annot_kws={"size": 16}, linewidths=0.0, linecolor='black', fmt=".2f")

    ax.tick_params(
        axis='both',      # apply to both axes
        which='both',     # apply to both major and minor ticks
        bottom=False,     # remove bottom ticks
        top=False,        # remove top ticks
        left=False,       # remove left ticks
        right=False,      # remove right ticks
        labelbottom=True, # keep labels if you want
        labelleft=True    # keep labels if you want
    )

    # Get the number of rows and columns
    n_rows, n_cols = matrix.shape

    # Add rectangle around the whole heatmap to complete the outer box
    rect = Rectangle(
        (0, 0),          # bottom left corner
        width=n_cols,    # number of columns
        height=n_rows,   # number of rows
        fill=False,      # no fill, just the edge
        edgecolor='black',
        linewidth=1.5
    )
    ax.add_patch(rect)

    # Draw thick lines between groups
    ax.axhline(boundary, color='black', linewidth=1, linestyle='--')
    ax.axvline(boundary, color='black', linewidth=1, linestyle='--')

    plt.savefig(os.path.join(plot_dir, f"{filename}.pdf"), bbox_inches='tight')
    plt.savefig(os.path.join(plot_dir, f"{filename}.png"), bbox_inches='tight')

# %%
# df_combined = pd.concat([df_PTH_clean, df_DPhiJ0J1_clean, df_NJ_clean, df_PTJ0_clean, df_rapidity_clean], axis=1)

df_combined_dict = {
    "PTH": df_PTH_clean,
    "DPhiJ0J1": df_DPhiJ0J1_clean,
    "NJ": df_NJ_clean,
    "PTJ0": df_PTJ0_clean,
    "rapidity": df_rapidity_clean
}

variable_names = ["PTH", "DPhiJ0J1", "NJ", "PTJ0", "rapidity"]
variable_pairs = list(combinations(variable_names, 2))

# Define group boundaries (between variable blocks)
group_boundaries = {
    "PTH": 8,
    "DPhiJ0J1": 6,
    "NJ": 4,
    "PTJ0": 5,
    "rapidity": 5
}

for i, (variable1, variable2) in enumerate(variable_pairs):
    df_combined_reduced = pd.concat([df_combined_dict[variable1], df_combined_dict[variable2]], axis=1)
    matrix = df_combined_reduced.corr()
    modified_matrix = matrix.copy()
    modified_matrix = modified_matrix.where(abs(modified_matrix) >= 0.01, 0)  # Set values greater than 0.1 to 0
    modified_matrix = modified_matrix.rename(index=translation, columns=translation)
    boundary = group_boundaries[variable1]
    filename = f"correlation_matrix_{variable1}vs{variable2}"
    plot_matrix(modified_matrix, boundary, filename)

# %%
z_hat = 0.5 * np.log((1 + corr_matrix) / (1 - corr_matrix)) + (corr_matrix / (2*(len(df_combined) - 2)))
a = np.tanh(z_hat - np.sqrt(1 / (len(df_combined) - 3)))
b = np.tanh(z_hat + np.sqrt(1 / (len(df_combined) - 3)))

# %%
b - corr_matrix

# %%
corr_matrix - a

# %%
# From Wikipedia https://en.wikipedia.org/wiki/Pearson_correlation_coefficient
np.sqrt((1 - corr_matrix**2) / (len(df_combined) - 2))

# %%
# Load combine toys
combineToy_dir = "/work/niharrin/t35/CMSSW_14_1_0_pre4/src/flashggFinalFit/Replicas/CombineToy_Validation/toys"
variable = "PTH"

pois_untrimmed_combineToys = create_json_untrimmed(variable, combineToy_dir, poi_list, extra_name="_combineToys")
pois_combineToys = create_json_trimmed(variable, combineToy_dir, pois_untrimmed_combineToys, poi_list, subfolder_=f"SL_{variable}", extra_name="_combineToys")

# %%
df_combine = pd.DataFrame(pois_untrimmed_combineToys)
# --- Step 1: Identify rows WITHOUT -999 in either DataFrame ---
# Mask for df_PTH (True = valid, False = -999)
mask_combine = (df_combine != -999).all(axis=1)

# --- Step 2: Filter DataFrames ---
df_combine = df_combine[mask_combine]

# Calculate full correlation matrix
corr_matrix_combine = df_combine.corr()

# %%
corr_matrix_combine
sns.heatmap(corr_matrix_combine, annot=True, cmap='coolwarm', vmin=-0.1, vmax=0.1)

# %%
# z = 5

# %%
# z = 1

# %%
# z = 2

# %%
# z = 4

# %%
np.corrcoef(df_combine["r_PTH_15p0_30p0"], df_combine["r_PTH_350p0_10000p0"])[0,1]

# %%
df_combine = pd.DataFrame(pois_combineToys)
# --- Step 1: Identify rows WITHOUT -999 in either DataFrame ---
# Mask for df_PTH (True = valid, False = -999)
mask_combine = (df_combine != -999).all(axis=1)

# --- Step 2: Filter DataFrames ---
df_combine = df_combine[mask_combine]

# Calculate full correlation matrix
corr_matrix_combine = df_combine.corr()
np.corrcoef(df_combine["r_PTH_15p0_30p0"], df_combine["r_PTH_350p0_10000p0"])[0,1]

# %%
plot_all_individual_correlation(pois_untrimmed_combineToys, poi_list, variable)

# %%
df_untrimmed_combine = pd.DataFrame(pois_untrimmed_combineToys)
# --- Step 1: Identify rows WITHOUT -999 in either DataFrame ---
# Mask for df_PTH (True = valid, False = -999)
mask_combine = (df_untrimmed_combine != -999).all(axis=1)

# --- Step 2: Filter DataFrames ---
df_untrimmed_combine = df_untrimmed_combine[mask_combine]

# Calculate full correlation matrix
corr_matrix_untrimmed_combine = df_untrimmed_combine.corr()

# %%
plt.figure(figsize=(18, 8))
sns.heatmap(corr_matrix_untrimmed_combine, annot=True, cmap='coolwarm', vmin=-0.1, vmax=0.1)

# %%
df_untrimmed_NJ = pd.DataFrame(pois_untrimmed_NJ)
df_untrimmed_PTJ0 = pd.DataFrame(pois_untrimmed_PTJ0)

# %%
df_untrimmed_NJ

# %%
df_untrimmed_PTJ0
